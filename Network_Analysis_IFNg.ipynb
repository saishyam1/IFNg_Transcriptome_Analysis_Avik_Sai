# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
network_data = pd.read_csv('1_Network_analysis_high_confidence.csv')

# %%
network_data.index = network_data.loc[:,'name']

# %%
network_data
# Out:
#           AverageShortestPathLength  BetweennessCentrality  \
# name
# H2-K1                      2.823529               0.013232
# Gm5431                     3.264706               0.000000
# Krtap2-4                   1.000000               0.000000
# Gm11562                    1.000000               0.000000
# H2-T24                     3.661765               0.000658
# ...                             ...                    ...
# Psmb9                      2.044118               0.093331
# Tap1                       2.102941               0.057391
# Tap2                       2.808824               0.000516
# H2-T23                     2.794118               0.019623
# H2-M2                      3.676471               0.000000
#
#           ClosenessCentrality  ClusteringCoefficient  Degree  degree.layout  \
# name
# H2-K1                0.354167               0.714286       7              7
# Gm5431               0.306306               0.000000       1              1
# Krtap2-4             1.000000               0.000000       1              1
# Gm11562              1.000000               0.000000       1              1
# H2-T24               0.273092               0.700000       5              5
# ...                       ...                    ...     ...            ...
# Psmb9                0.489209               0.410256      13             13
# Tap1                 0.475524               0.611111       9              9
# Tap2                 0.356021               0.809524       7              7
# H2-T23               0.357895               0.678571       8              8
# H2-M2                0.272000               1.000000       4              4
#
#           Eccentricity  IsSingleNode  Mean_log2FC      name  \
# name
# H2-K1                4         False     0.928787     H2-K1
# Gm5431               5         False     1.298088    Gm5431
# Krtap2-4             1         False     1.766494  Krtap2-4
# Gm11562              1         False     1.877261   Gm11562
# H2-T24               5         False     2.819303    H2-T24
# ...                ...           ...          ...       ...
# Psmb9                4         False     3.395791     Psmb9
# Tap1                 4         False     3.041509      Tap1
# Tap2                 4         False     1.827103      Tap2
# H2-T23               4         False     2.464653    H2-T23
# H2-M2                5         False     1.697941     H2-M2
#
#           NeighborhoodConnectivity  NumberOfDirectedEdges  \
# name
# H2-K1                     8.428571                      0
# Gm5431                   10.000000                      0
# Krtap2-4                  1.000000                      0
# Gm11562                   1.000000                      0
# H2-T24                    6.600000                      0
# ...                            ...                    ...
# Psmb9                    10.923077                      0
# Tap1                     14.000000                      0
# Tap2                     10.000000                      0
# H2-T23                    8.875000                      0
# H2-M2                     8.000000                      0
#
#           NumberOfUndirectedEdges  PartnerOfMultiEdgedNodePairs  Radiality  \
# name
# H2-K1                           7                             0   0.954412
# Gm5431                          1                             0   0.943382
# Krtap2-4                        1                             0   1.000000
# Gm11562                         1                             0   1.000000
# H2-T24                          5                             0   0.933456
# ...                           ...                           ...        ...
# Psmb9                          13                             0   0.973897
# Tap1                            9                             0   0.972426
# Tap2                            7                             0   0.954779
# H2-T23                          8                             0   0.955147
# H2-M2                           4                             0   0.933088
#
#           selected  SelfLoops shared name  Stress  TopologicalCoefficient
# name
# H2-K1        False          0       H2-K1     928                0.443609
# Gm5431       False          0      Gm5431       0                0.000000
# Krtap2-4     False          0    Krtap2-4       0                0.000000
# Gm11562      False          0     Gm11562       0                0.000000
# H2-T24       False          0      H2-T24       6                0.550000
# ...            ...        ...         ...     ...                     ...
# Psmb9        False          0       Psmb9    2750                0.206096
# Tap1         False          0        Tap1    2336                0.264151
# Tap2         False          0        Tap2      10                0.500000
# H2-T23       False          0      H2-T23    1356                0.443750
# H2-M2        False          0       H2-M2       0                0.666667
#
# [78 rows x 20 columns]

# %%
network_data
# Out:
#           AverageShortestPathLength  BetweennessCentrality  \
# name
# H2-K1                      2.823529               0.013232
# Gm5431                     3.264706               0.000000
# Krtap2-4                   1.000000               0.000000
# Gm11562                    1.000000               0.000000
# H2-T24                     3.661765               0.000658
# ...                             ...                    ...
# Psmb9                      2.044118               0.093331
# Tap1                       2.102941               0.057391
# Tap2                       2.808824               0.000516
# H2-T23                     2.794118               0.019623
# H2-M2                      3.676471               0.000000
#
#           ClosenessCentrality  ClusteringCoefficient  Degree  degree.layout  \
# name
# H2-K1                0.354167               0.714286       7              7
# Gm5431               0.306306               0.000000       1              1
# Krtap2-4             1.000000               0.000000       1              1
# Gm11562              1.000000               0.000000       1              1
# H2-T24               0.273092               0.700000       5              5
# ...                       ...                    ...     ...            ...
# Psmb9                0.489209               0.410256      13             13
# Tap1                 0.475524               0.611111       9              9
# Tap2                 0.356021               0.809524       7              7
# H2-T23               0.357895               0.678571       8              8
# H2-M2                0.272000               1.000000       4              4
#
#           Eccentricity  IsSingleNode  Mean_log2FC      name  \
# name
# H2-K1                4         False     0.928787     H2-K1
# Gm5431               5         False     1.298088    Gm5431
# Krtap2-4             1         False     1.766494  Krtap2-4
# Gm11562              1         False     1.877261   Gm11562
# H2-T24               5         False     2.819303    H2-T24
# ...                ...           ...          ...       ...
# Psmb9                4         False     3.395791     Psmb9
# Tap1                 4         False     3.041509      Tap1
# Tap2                 4         False     1.827103      Tap2
# H2-T23               4         False     2.464653    H2-T23
# H2-M2                5         False     1.697941     H2-M2
#
#           NeighborhoodConnectivity  NumberOfDirectedEdges  \
# name
# H2-K1                     8.428571                      0
# Gm5431                   10.000000                      0
# Krtap2-4                  1.000000                      0
# Gm11562                   1.000000                      0
# H2-T24                    6.600000                      0
# ...                            ...                    ...
# Psmb9                    10.923077                      0
# Tap1                     14.000000                      0
# Tap2                     10.000000                      0
# H2-T23                    8.875000                      0
# H2-M2                     8.000000                      0
#
#           NumberOfUndirectedEdges  PartnerOfMultiEdgedNodePairs  Radiality  \
# name
# H2-K1                           7                             0   0.954412
# Gm5431                          1                             0   0.943382
# Krtap2-4                        1                             0   1.000000
# Gm11562                         1                             0   1.000000
# H2-T24                          5                             0   0.933456
# ...                           ...                           ...        ...
# Psmb9                          13                             0   0.973897
# Tap1                            9                             0   0.972426
# Tap2                            7                             0   0.954779
# H2-T23                          8                             0   0.955147
# H2-M2                           4                             0   0.933088
#
#           selected  SelfLoops shared name  Stress  TopologicalCoefficient
# name
# H2-K1        False          0       H2-K1     928                0.443609
# Gm5431       False          0      Gm5431       0                0.000000
# Krtap2-4     False          0    Krtap2-4       0                0.000000
# Gm11562      False          0     Gm11562       0                0.000000
# H2-T24       False          0      H2-T24       6                0.550000
# ...            ...        ...         ...     ...                     ...
# Psmb9        False          0       Psmb9    2750                0.206096
# Tap1         False          0        Tap1    2336                0.264151
# Tap2         False          0        Tap2      10                0.500000
# H2-T23       False          0      H2-T23    1356                0.443750
# H2-M2        False          0       H2-M2       0                0.666667
#
# [78 rows x 20 columns]

# %%
Hub_bottle_necks = pd.read_excel("Node_table_high_confidence.xlsx")

# %%
import pandas as pd


excel_file = pd.ExcelFile("Node_table_high_confidence.xlsx")


sheet_names = excel_file.sheet_names
sheet1_data = pd.read_excel(excel_file, sheet_name=sheet_names[0])

sheet2_data = pd.read_excel(excel_file, sheet_name=sheet_names[1])


sheet3_data = pd.read_excel(excel_file, sheet_name=sheet_names[2])
# excel_file
# excel_file.sheet_names

# %%
sheet1_data
# Out:
#     AverageShortestPathLength  BetweennessCentrality  ClosenessCentrality  \
# 0                    3.676471               0.000000             0.272000
# 1                    2.794118               0.019623             0.357895
# 2                    2.808824               0.000516             0.356021
# 3                    2.102941               0.057391             0.475524
# 4                    2.044118               0.093331             0.489209
# ..                        ...                    ...                  ...
# 73                   3.661765               0.000658             0.273092
# 74                   1.000000               0.000000             1.000000
# 75                   1.000000               0.000000             1.000000
# 76                   3.264706               0.000000             0.306306
# 77                   2.823529               0.013232             0.354167
#
#     ClusteringCoefficient  Degree  degree.layout  Eccentricity  IsSingleNode  \
# 0                1.000000       4              4             5         False
# 1                0.678571       8              8             4         False
# 2                0.809524       7              7             4         False
# 3                0.611111       9              9             4         False
# 4                0.410256      13             13             4         False
# ..                    ...     ...            ...           ...           ...
# 73               0.700000       5              5             5         False
# 74               0.000000       1              1             1         False
# 75               0.000000       1              1             1         False
# 76               0.000000       1              1             5         False
# 77               0.714286       7              7             4         False
#
#     Mean_log2FC      name  NeighborhoodConnectivity  NumberOfDirectedEdges  \
# 0      1.697941     H2-M2                  8.000000                      0
# 1      2.464653    H2-T23                  8.875000                      0
# 2      1.827103      Tap2                 10.000000                      0
# 3      3.041509      Tap1                 14.000000                      0
# 4      3.395791     Psmb9                 10.923077                      0
# ..          ...       ...                       ...                    ...
# 73     2.819303    H2-T24                  6.600000                      0
# 74     1.877261   Gm11562                  1.000000                      0
# 75     1.766494  Krtap2-4                  1.000000                      0
# 76     1.298088    Gm5431                 10.000000                      0
# 77     0.928787     H2-K1                  8.428571                      0
#
#     NumberOfUndirectedEdges  PartnerOfMultiEdgedNodePairs  Radiality  \
# 0                         4                             0   0.933088
# 1                         8                             0   0.955147
# 2                         7                             0   0.954779
# 3                         9                             0   0.972426
# 4                        13                             0   0.973897
# ..                      ...                           ...        ...
# 73                        5                             0   0.933456
# 74                        1                             0   1.000000
# 75                        1                             0   1.000000
# 76                        1                             0   0.943382
# 77                        7                             0   0.954412
#
#     selected  SelfLoops shared name  Stress  TopologicalCoefficient
# 0      False          0       H2-M2       0                0.666667
# 1      False          0      H2-T23    1356                0.443750
# 2      False          0        Tap2      10                0.500000
# 3      False          0        Tap1    2336                0.264151
# 4      False          0       Psmb9    2750                0.206096
# ..       ...        ...         ...     ...                     ...
# 73     False          0      H2-T24       6                0.550000
# 74     False          0     Gm11562       0                0.000000
# 75     False          0    Krtap2-4       0                0.000000
# 76     False          0      Gm5431       0                0.000000
# 77     False          0       H2-K1     928                0.443609
#
# [78 rows x 20 columns]

# %%
sheet2_data
# Out:
#    Name (Yellow hubs)  Degree  BetweennessCentrality
# 0               Stat1      40               0.460312
# 1                Irf7      21               0.063256
# 2                Irf1      20               0.092895
# 3              Cxcl10      18               0.057905
# 4               Isg15      18               0.068774
# ..                ...     ...                    ...
# 73              Tgtp1       1               0.000000
# 74              Erap1       1               0.000000
# 75            Gm11562       1               0.000000
# 76           Krtap2-4       1               0.000000
# 77             Gm5431       1               0.000000
#
# [78 rows x 3 columns]

# %%
sheet3_data
# Out:
#         name  Degree  BetweennessCentrality  \
# 0      Stat1      40               0.460312
# 1      Psmb8      14               0.143521
# 2      Psmb9      13               0.093331
# 3       Irf1      20               0.092895
# 4      Tapbp      12               0.080155
# ..       ...     ...                    ...
# 73     Tgtp1       1               0.000000
# 74     Erap1       1               0.000000
# 75   Gm11562       1               0.000000
# 76  Krtap2-4       1               0.000000
# 77    Gm5431       1               0.000000
#
#    Bottlenecks (Interacting Nodes, at least two hubs)
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 73                                                NaN
# 74                                                NaN
# 75                                                NaN
# 76                                                NaN
# 77                                                NaN
#
# [78 rows x 4 columns]

# %%
# pd.read_csv("string_interactions_short_oneway_edge_cytoscape.tsv default node.csv")

# %%
Upred_IFNg_log2  = pd.read_excel("Upreg_Control_vs_IFNg_log2FC.xlsx")
Upred_IFNg_log2
# Out:
#          gene_name  Mean_log2FC
# 0             Gbp2     6.240483
# 1        Serpina3g     6.068251
# 2        Serpina3f     6.034259
# 3            Tgtp2     5.708683
# 4            Gbp2b     5.622738
# ..             ...          ...
# 122  1700034J05Rik     0.813588
# 123         Gm8300     0.802321
# 124          Rbm43     0.768703
# 125            Pnp     0.700562
# 126           Pnp2     0.659276
#
# [127 rows x 2 columns]

# %%
sheet3_data
# Out:
#         name  Degree  BetweennessCentrality  \
# 0      Stat1      40               0.460312
# 1      Psmb8      14               0.143521
# 2      Psmb9      13               0.093331
# 3       Irf1      20               0.092895
# 4      Tapbp      12               0.080155
# ..       ...     ...                    ...
# 73     Tgtp1       1               0.000000
# 74     Erap1       1               0.000000
# 75   Gm11562       1               0.000000
# 76  Krtap2-4       1               0.000000
# 77    Gm5431       1               0.000000
#
#    Bottlenecks (Interacting Nodes, at least two hubs)
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 73                                                NaN
# 74                                                NaN
# 75                                                NaN
# 76                                                NaN
# 77                                                NaN
#
# [78 rows x 4 columns]

# %%
joined_df = pd.merge( sheet2_data,Upred_IFNg_log2, left_on="Name (Yellow hubs)", right_on="gene_name", how="left")
joined_df
# Out:
#    Name (Yellow hubs)  Degree  BetweennessCentrality gene_name  Mean_log2FC
# 0               Stat1      40               0.460312     Stat1     2.933736
# 1                Irf7      21               0.063256      Irf7     2.283998
# 2                Irf1      20               0.092895      Irf1     3.893480
# 3              Cxcl10      18               0.057905    Cxcl10     4.012487
# 4               Isg15      18               0.068774     Isg15     2.985464
# ..                ...     ...                    ...       ...          ...
# 73              Tgtp1       1               0.000000     Tgtp1     4.849469
# 74              Erap1       1               0.000000     Erap1     1.599159
# 75            Gm11562       1               0.000000   Gm11562     1.877261
# 76           Krtap2-4       1               0.000000  Krtap2-4     1.766494
# 77             Gm5431       1               0.000000    Gm5431     1.298088
#
# [78 rows x 5 columns]

# %%
sorted_joined_df = joined_df.sort_values(by='Degree', ascending=False)
hubs_only = sorted_joined_df[sorted_joined_df.loc[:,'Degree'] >= 12]
hubs_only
# Out:
#    Name (Yellow hubs)  Degree  BetweennessCentrality gene_name  Mean_log2FC
# 0               Stat1      40               0.460312     Stat1     2.933736
# 1                Irf7      21               0.063256      Irf7     2.283998
# 2                Irf1      20               0.092895      Irf1     3.893480
# 3              Cxcl10      18               0.057905    Cxcl10     4.012487
# 4               Isg15      18               0.068774     Isg15     2.985464
# 5                 Il6      17               0.039147       Il6     1.459508
# 6                Il1b      15               0.042406      Il1b     1.272395
# 7                Irf9      15               0.012499      Irf9     1.838414
# 9                Gbp3      14               0.030286      Gbp3     4.641856
# 10              Psmb8      14               0.143521     Psmb8     2.225751
# 8               Stat2      14               0.010214     Stat2     1.542010
# 11              Psmb9      13               0.093331     Psmb9     3.395791
# 12               Gbp2      13               0.059062      Gbp2     6.240483
# 13              Dhx58      12               0.014098     Dhx58     1.494521
# 14              Tapbp      12               0.080155     Tapbp     1.523009

# %% [markdown]
# Scatter plots hubs and all together

# %%
# import seaborn as sns
# import scipy.stats as stats

# plt.figure(dpi = 200)
# # Create the lmplot
# sns.lmplot(x='Degree', y='Mean_log2FC', data=hubs_only)

# # Calculate Spearman correlation coefficient and p-value
# spearman_corr, p_value = stats.spearmanr(hubs_only['Degree'], hubs_only['Mean_log2FC'])

# # Annotate the plot with the Spearman correlation coefficient and p-value
# plt.annotate(f"Spearman correlation: {spearman_corr:.2f}\np-value: {p_value:.2f}", xy=(0.5, 0.9), xycoords='axes fraction', ha='center')

# # Show the plot
# plt.show()

# %%
# import seaborn as sns
# import scipy.stats as stats
# plt.figure(dpi = 200)
# # Create the lmplot
# sns.lmplot(x='Degree', y='Mean_log2FC', data=joined_df)

# # Calculate Spearman correlation coefficient and p-value
# spearman_corr, p_value = stats.spearmanr(joined_df['Degree'], joined_df['Mean_log2FC'])

# # Annotate the plot with the Spearman correlation coefficient and p-value
# plt.annotate(f"Spearman correlation: {spearman_corr:.2f}\np-value: {p_value:.2f}", xy=(0.5, 0.9), xycoords='axes fraction', ha='center')

# # Show the plot
# plt.show()

# %%
# import seaborn as sns
# import scipy.stats as stats
# import matplotlib.pyplot as plt

# plt.figure(dpi=200)

# # Create the lmplot with hue
# sns.lmplot(x='Degree', y='Mean_log2FC', data=joined_df, hue='BetweennessCentrality')

# # Calculate Spearman correlation coefficient and p-value
# spearman_corr, p_value = stats.spearmanr(joined_df['Degree'], joined_df['Mean_log2FC'])

# # Annotate the plot with the Spearman correlation coefficient and p-value
# plt.annotate(f"Spearman correlation: {spearman_corr:.2f}\np-value: {p_value:.2f}", xy=(0.5, 0.9), xycoords='axes fraction', ha='center')

# # Show the plot
# plt.show()

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt
# import pandas as pd
# import numpy as np
# import scipy.stats as stats

# # Extract the selected columns from joined_df
# selected_columns = joined_df[['Degree', 'BetweennessCentrality', 'Mean_log2FC']]

# # Calculate the Spearman correlation and p-values
# spearman_corr, p_values = stats.spearmanr(selected_columns, axis=0)

# # Create the heatmap
# plt.figure(figsize=(8, 6))
# sns.heatmap(selected_columns.corr(), cmap='coolwarm', fmt=".2f")

# # Annotate the heatmap with Spearman correlation coefficient and p-values
# for i in range(len(selected_columns.columns)):
#     for j in range(len(selected_columns.columns)):
#         if i != j:
#             plt.text(j + 0.5, i + 0.5, f"Spearman: {spearman_corr[i, j]:.2f}\np-value: {p_values[i, j]:.2f}",
#                      ha='center', va='center', color='black', fontsize=8)

# # Add title
# plt.title('Correlation Heatmap with Spearman Correlation and P-values')

# # Show the plot
# plt.show()

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt
# import pandas as pd
# import numpy as np
# import scipy.stats as stats

# # Extract the selected columns from joined_df
# selected_columns = joined_df[['Degree', 'BetweennessCentrality', 'Mean_log2FC']]

# # Calculate the Spearman correlation and p-values
# spearman_corr, p_values = stats.spearmanr(selected_columns, axis=0)

# # Create the pair plot
# pair_plot = sns.pairplot(selected_columns)

# # Annotate the pair plot with Spearman correlation coefficient and p-values
# for i, col1 in enumerate(selected_columns.columns):
#     for j, col2 in enumerate(selected_columns.columns):
#         if i != j:
#             p_val = p_values[i, j]
#             if p_val < 0.0001:
#                 p_val_str = '< 10e-4'
#             else:
#                 p_val_str = f'{p_val:.4f}'
#             pair_plot.axes[i, j].text(0.7, 0.95, f"Spearman: {spearman_corr[i, j]:.2f}\n p-value: {p_val_str}",
#                                       ha='center', va='center', transform=pair_plot.axes[i, j].transAxes,
#                                       fontsize=8, color='black')

# # Add linear regression lines and correct labels
# for i, col1 in enumerate(selected_columns.columns):
#     for j, col2 in enumerate(selected_columns.columns):
#         if i != j:
#             sns.regplot(x=col2, y=col1, data=selected_columns, ax=pair_plot.axes[i, j], line_kws={"color":"red"})
#             pair_plot.axes[i, j].set_xlabel(col2)
#             pair_plot.axes[i, j].set_ylabel(col1)

# # Show the plot
# plt.tight_layout()
# plt.show()

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt
# import pandas as pd
# import numpy as np
# import scipy.stats as stats

# # Extract the selected columns from joined_df
# selected_columns = joined_df[['Degree', 'BetweennessCentrality', 'Mean_log2FC']]

# # Calculate the Spearman correlation and p-values
# spearman_corr, p_values = stats.spearmanr(selected_columns, axis=0)

# # Create a figure and axes for the plots
# fig, axes = plt.subplots(2, 3, figsize=(15, 10))

# # Plot correlation plots in the first row
# for i, (x_col, y_col) in enumerate([('BetweennessCentrality', 'Degree'), ('Mean_log2FC', 'BetweennessCentrality'), ('Degree', 'Mean_log2FC')]):
#     sns.regplot(x=x_col, y=y_col, data=selected_columns, ax=axes[0, i], line_kws={"color":"red"})
#     axes[0, i].set_xlabel(x_col, fontsize=12)
#     axes[0, i].set_ylabel(y_col, fontsize=12)
#     p_val = p_values[i, (i + 1) % 3]
#     if p_val < 10e-4:
#         p_val_str = 'p < 10e-4'
#     else:
#         p_val_str = f'p = {p_val:.4f}'
#     axes[0, i].text(0.7, 0.95, f"Spearman: {spearman_corr[i, (i + 1) % 3]:.2f}\n{p_val_str}",
#                     ha='center', va='center', transform=axes[0, i].transAxes, fontsize=12, color='black')

# # Plot KDE distributions in the second row
# for i, col in enumerate(['Degree', 'BetweennessCentrality', 'Mean_log2FC']):
#     sns.kdeplot(selected_columns[col], ax=axes[1, i])
#     axes[1, i].set_xlabel(col, fontsize=12)

# # Adjust layout
# plt.tight_layout()
# plt.show()

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt
# import pandas as pd
# import numpy as np
# import scipy.stats as stats

# # Extract the selected columns from joined_df
# selected_columns = joined_df[['Degree', 'BetweennessCentrality', 'Mean_log2FC']]

# # Calculate the Spearman correlation and p-values
# spearman_corr, p_values = stats.spearmanr(selected_columns, axis=0)

# # Create a figure and axes for the plots
# fig, axes = plt.subplots(2, 3, figsize=(15, 10))

# # Plot correlation plots in the first row
# for i, (x_col, y_col) in enumerate([('BetweennessCentrality', 'Degree'), ('Mean_log2FC', 'BetweennessCentrality'), ('Degree', 'Mean_log2FC')]):
#     sns.regplot(x=x_col, y=y_col, data=selected_columns, ax=axes[0, i], line_kws={"color":"red"})
#     axes[0, i].set_xlabel(x_col, fontsize=12, fontweight='bold')
#     axes[0, i].set_ylabel(y_col, fontsize=12, fontweight='bold')
#     p_val = p_values[i, (i + 1) % 3]
#     if p_val < 10e-4:
#         p_val_str = 'p < 10e-4'
#     else:
#         p_val_str = f'p = {p_val:.4f}'
#     axes[0, i].text(0.7, 0.9, f"Spearman: {spearman_corr[i, (i + 1) % 3]:.2f}\n{p_val_str}",
#                     ha='center', va='center', transform=axes[0, i].transAxes, fontsize=12, color='black')

# # Plot KDE distributions in the second row
# for i, col in enumerate(['Degree', 'BetweennessCentrality', 'Mean_log2FC']):
#     sns.histplot(selected_columns[col], kde=True, ax=axes[1, i], color='blue', linewidth=1)
#     # sns.kdeplot(selected_columns[col], ax=axes[1, i], color='red', linewidth=1)
#     axes[1, i].set_xlabel(col, fontsize=12, fontweight='bold')

# # Adjust layout
# plt.tight_layout()
# plt.show()

# %% [markdown]
# **Finalized plot**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as stats

# Extract the selected columns from joined_df
selected_columns = joined_df[['Degree', 'BetweennessCentrality', 'Mean_log2FC']]

# Calculate the Spearman correlation and p-values
spearman_corr, p_values = stats.spearmanr(selected_columns, axis=0)

# Create a figure and axes for the plots
fig, axes = plt.subplots(2, 3, figsize=(15, 10))

# Define bin sizes for KDE plots
bin_sizes = [20, 30, 40]  # Adjust as needed

# Plot KDE distributions in the first row
for i, (col, bin_size) in enumerate(zip(['Degree', 'BetweennessCentrality', 'Mean_log2FC'], bin_sizes)):
    sns.histplot(selected_columns[col], kde=True, bins=bin_size, ax=axes[0, i], color='blue', linewidth=1, alpha=0.2)
    axes[0, i].set_xlabel('Degree', fontsize=16, fontweight='bold') if col == 'Degree' else axes[0, i].set_xlabel('Betweenness Centrality', fontsize=14, fontweight='bold') if col == 'BetweennessCentrality' else axes[0, i].set_xlabel('Log2 (Fold Change)', fontsize=16)
    axes[0, i].set_ylabel('Frequency', fontsize=16, fontweight='bold')  # Set y-axis label to "Frequency"
    axes[0, i].tick_params(axis='x', labelsize=16)  # Increase x tick label size
    axes[0, i].tick_params(axis='y', labelsize=16)  # Increase y tick label size
    axes[0, i].grid(False)  # Turn off grid

# Plot correlation plots in the second row
for i, (x_col, y_col) in enumerate([('BetweennessCentrality', 'Degree'), ('Mean_log2FC', 'BetweennessCentrality'), ('Degree', 'Mean_log2FC')]):
    sns.regplot(x=x_col, y=y_col, data=selected_columns, ax=axes[1, i], line_kws={"color":"red"})
    axes[1, i].set_xlabel('Betweenness Centrality', fontsize=16, fontweight='bold') if x_col == 'BetweennessCentrality' else axes[1, i].set_xlabel('Log2 (Fold Change)', fontsize=16, fontweight='bold') if x_col == 'Mean_log2FC' else axes[1, i].set_xlabel('Degree', fontsize=16, fontweight='bold')
    axes[1, i].set_ylabel('Degree', fontsize=16, fontweight='bold') if y_col == 'Degree' else axes[1, i].set_ylabel('\nBetweenness Centrality', fontsize=16, fontweight='bold') if y_col == 'BetweennessCentrality' else axes[1, i].set_ylabel('Log2 (Fold Change)', fontsize=16, fontweight='bold')
    p_val = p_values[i, (i + 1) % 3]
    if p_val < 10e-4:
        p_val_str = 'p < 10⁻⁴'
    else:
        p_val_str = f'p = {p_val:.4f}'
    axes[1, i].text(0.7, 0.9, f"Spearman: {spearman_corr[i, (i + 1) % 3]:.2f}\n{p_val_str}",
                    ha='center', va='center', transform=axes[1, i].transAxes, fontsize=16, color='black')
    axes[1, i].tick_params(axis='x', labelsize=16)  # Increase x tick label size
    axes[1, i].tick_params(axis='y', labelsize=16)  # Increase y tick label size
    axes[1, i].grid(False)  # Turn off grid

# Adjust layout
plt.tight_layout()
plt.savefig("Network_paramsters_scatter_.png", dpi=500)
plt.show()

# %%
####### HUBS ONLY

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as stats

# Extract the selected columns from joined_df
selected_columns = hubs_only[['Degree', 'BetweennessCentrality', 'Mean_log2FC']]

# Calculate the Spearman correlation and p-values
spearman_corr, p_values = stats.spearmanr(selected_columns, axis=0)

# Create a figure and axes for the plots
fig, axes = plt.subplots(2, 3, figsize=(15, 10))

# Define bin sizes for KDE plots
bin_sizes = [20, 30, 40]  # Adjust as needed

# Plot KDE distributions in the first row
for i, (col, bin_size) in enumerate(zip(['Degree', 'BetweennessCentrality', 'Mean_log2FC'], bin_sizes)):
    sns.histplot(selected_columns[col], kde=True, bins=bin_size, ax=axes[0, i], color='blue', linewidth=1, alpha=0.2)
    axes[0, i].set_xlabel('Degree', fontsize=16, fontweight='bold') if col == 'Degree' else axes[0, i].set_xlabel('Betweenness Centrality', fontsize=14, fontweight='bold') if col == 'BetweennessCentrality' else axes[0, i].set_xlabel('Log2 (Fold Change)', fontsize=16)
    axes[0, i].set_ylabel('Frequency', fontsize=16, fontweight='bold')  # Set y-axis label to "Frequency"
    axes[0, i].tick_params(axis='x', labelsize=16)  # Increase x tick label size
    axes[0, i].tick_params(axis='y', labelsize=16)  # Increase y tick label size
    axes[0, i].grid(False)  # Turn off grid

# Plot correlation plots in the second row
for i, (x_col, y_col) in enumerate([('BetweennessCentrality', 'Degree'), ('Mean_log2FC', 'BetweennessCentrality'), ('Degree', 'Mean_log2FC')]):
    sns.regplot(x=x_col, y=y_col, data=selected_columns, ax=axes[1, i], line_kws={"color":"red"})
    axes[1, i].set_xlabel('Betweenness Centrality', fontsize=16, fontweight='bold') if x_col == 'BetweennessCentrality' else axes[1, i].set_xlabel('Log2 (Fold Change)', fontsize=16, fontweight='bold') if x_col == 'Mean_log2FC' else axes[1, i].set_xlabel('Degree', fontsize=16, fontweight='bold')
    axes[1, i].set_ylabel('Degree', fontsize=16, fontweight='bold') if y_col == 'Degree' else axes[1, i].set_ylabel('\nBetweenness Centrality', fontsize=16, fontweight='bold') if y_col == 'BetweennessCentrality' else axes[1, i].set_ylabel('Log2 (Fold Change)', fontsize=16, fontweight='bold')
    p_val = p_values[i, (i + 1) % 3]
    if p_val < 10e-4:
        p_val_str = 'p < 10⁻⁴'
    else:
        p_val_str = f'p = {p_val:.4f}'
    axes[1, i].text(0.7, 0.9, f"Spearman: {spearman_corr[i, (i + 1) % 3]:.2f}\n{p_val_str}",
                    ha='center', va='center', transform=axes[1, i].transAxes, fontsize=16, color='black')
    axes[1, i].tick_params(axis='x', labelsize=16)  # Increase x tick label size
    axes[1, i].tick_params(axis='y', labelsize=16)  # Increase y tick label size
    axes[1, i].grid(False)  # Turn off grid

# Adjust layout
plt.tight_layout()
plt.savefig("Network_paramsters_scatter_hubs_only.png", dpi=500)
plt.show()

# %% [markdown]
# Only Hubs

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt
# import pandas as pd
# import numpy as np
# import scipy.stats as stats

# # Extract the selected columns from joined_df
# selected_columns = hubs_only[['Degree', 'BetweennessCentrality', 'Mean_log2FC']]

# # Calculate the Spearman correlation and p-values
# spearman_corr, p_values = stats.spearmanr(selected_columns, axis=0)

# # Create a figure and axes for the plots
# fig, axes = plt.subplots(2, 3, figsize=(15, 10))

# # Define bin sizes for KDE plots
# bin_sizes = [20, 30, 40]  # Adjust as needed

# # Plot KDE distributions in the first row
# for i, (col, bin_size) in enumerate(zip(['Degree', 'BetweennessCentrality', 'Mean_log2FC'], bin_sizes)):
#     sns.histplot(selected_columns[col], kde=True, bins=bin_size, ax=axes[0, i], color='blue', linewidth=1, alpha=0.1)
#     axes[0, i].set_xlabel(col, fontsize=16, fontweight='bold')
#     axes[0, i].set_ylabel('Frequency', fontsize=16, fontweight='bold')  # Set y-axis label to "Frequency"
#     axes[0, i].tick_params(axis='x', labelsize=16)  # Increase x tick label size
#     axes[0, i].tick_params(axis='y', labelsize=16)  # Increase y tick label size

# # Plot correlation plots in the second row
# for i, (x_col, y_col) in enumerate([('BetweennessCentrality', 'Degree'), ('Mean_log2FC', 'BetweennessCentrality'), ('Degree', 'Mean_log2FC')]):
#     sns.regplot(x=x_col, y=y_col, data=selected_columns, ax=axes[1, i], line_kws={"color":"red"})
#     axes[1, i].set_xlabel(x_col, fontsize=16, fontweight='bold')
#     axes[1, i].set_ylabel(y_col, fontsize=16, fontweight='bold')
#     p_val = p_values[i, (i + 1) % 3]
#     if p_val < 10e-4:
#         p_val_str = 'p < 10⁻⁴'
#     else:
#         p_val_str = f'p = {p_val:.4f}'
#     axes[1, i].text(0.7, 0.9, f"Spearman: {spearman_corr[i, (i + 1) % 3]:.2f}\n{p_val_str}",
#                     ha='center', va='center', transform=axes[1, i].transAxes, fontsize=16, color='black')
#     axes[1, i].tick_params(axis='x', labelsize=16)  # Increase x tick label size
#     axes[1, i].tick_params(axis='y', labelsize=16)  # Increase y tick label size

# # Adjust layout
# plt.tight_layout()
# plt.show()

# %%
hubs_only
# Out:
#    Name (Yellow hubs)  Degree  BetweennessCentrality gene_name  Mean_log2FC
# 0               Stat1      40               0.460312     Stat1     2.933736
# 1                Irf7      21               0.063256      Irf7     2.283998
# 2                Irf1      20               0.092895      Irf1     3.893480
# 3              Cxcl10      18               0.057905    Cxcl10     4.012487
# 4               Isg15      18               0.068774     Isg15     2.985464
# 5                 Il6      17               0.039147       Il6     1.459508
# 6                Il1b      15               0.042406      Il1b     1.272395
# 7                Irf9      15               0.012499      Irf9     1.838414
# 9                Gbp3      14               0.030286      Gbp3     4.641856
# 10              Psmb8      14               0.143521     Psmb8     2.225751
# 8               Stat2      14               0.010214     Stat2     1.542010
# 11              Psmb9      13               0.093331     Psmb9     3.395791
# 12               Gbp2      13               0.059062      Gbp2     6.240483
# 13              Dhx58      12               0.014098     Dhx58     1.494521
# 14              Tapbp      12               0.080155     Tapbp     1.523009

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt

# # Filter the data for hubs_only and select the required columns
# hubs_only_data = hubs_only[['Name (Yellow hubs)', 'Mean_log2FC', 'Degree']]

# # Sort the data by 'Degree' in ascending order
# hubs_only_data = hubs_only_data.sort_values(by='Degree',ascending = False)

# # Set the style
# sns.set(style="whitegrid")

# # Create the scatter plot
# plt.figure(figsize=(10, 6))
# sns.scatterplot(data=hubs_only_data, x='Name (Yellow hubs)', y='Mean_log2FC', hue='Degree', palette='coolwarm')

# # Rotate x-axis labels for better readability
# plt.xticks(rotation=45, ha='right')

# # Set labels and title
# plt.xlabel('Name (Yellow hubs)', fontsize=12)
# plt.ylabel('Mean_log2FC', fontsize=12)
# plt.title('Scatter Plot of Mean_log2FC vs Name (Yellow hubs)', fontsize=14)

# # Show legend
# plt.legend(title='Degree', fontsize=10)

# # Show plot
# plt.tight_layout()
# plt.savefig(".tif", dpi=500)
# plt.show()

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt

# # Filter the data for hubs_only and select the required columns
# hubs_only_data = hubs_only[['Name (Yellow hubs)', 'Mean_log2FC', 'Degree']]

# # Sort the data by 'Degree' in ascending order
# hubs_only_data = hubs_only_data.sort_values(by='Mean_log2FC')

# # Set the style
# sns.set(style="whitegrid")

# # Create the scatter plot
# plt.figure(figsize=(10, 6))
# sns.scatterplot(data=hubs_only_data, x='Name (Yellow hubs)', y='Mean_log2FC', hue='Degree', palette='coolwarm')

# # Rotate x-axis labels for better readability
# plt.xticks(rotation=45, ha='right')

# # Set labels and title
# plt.xlabel('Name (Yellow hubs)', fontsize=12)
# plt.ylabel('Mean_log2FC', fontsize=12)
# plt.title('Scatter Plot of Mean_log2FC vs Name (Yellow hubs)', fontsize=14)

# # Show legend
# plt.legend(title='Degree', fontsize=10)

# # Show plot
# plt.tight_layout()
# plt.show()

# %% [markdown]
# Below Plot Fixed

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats

# Filter the data for hubs_only and select the required columns
hubs_only_data = hubs_only[['Name (Yellow hubs)', 'Mean_log2FC', 'BetweennessCentrality', 'Degree']]

# Sort the data by 'Degree' in ascending order
hubs_only_data = hubs_only_data.sort_values(by='Degree', ascending=False)

# Set the style
sns.set(style="whitegrid")

# Create the scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(data=hubs_only_data, x='Name (Yellow hubs)', y='Mean_log2FC', hue='Degree', palette='coolwarm',s =100)  # Adjust 's' as needed

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right',fontsize=16)
plt.yticks(fontsize=16)

# Set labels and title
plt.xlabel('Hub Names', fontsize=16,fontweight='bold')
plt.ylabel('Log2 (Fold Change)', fontsize=16, fontweight='bold')
# plt.title('Scatter Plot of Mean_log2FC vs Name (Yellow hubs)', fontsize=14)

# Show legend
plt.legend(title='Degree', fontsize=14)

# Calculate Spearman correlation and p-value
spearman_corr, p_value = stats.spearmanr(hubs_only_data['Mean_log2FC'], hubs_only_data['BetweennessCentrality'])

# Annotate the plot with Spearman correlation coefficient and p-value
plt.text(0.2, 0.8, f"Spearman: {spearman_corr:.2f}\n p-value: {p_value:.4f}",
         ha='center', va='center', transform=plt.gca().transAxes, fontsize=16, color='black', bbox=dict(facecolor='white', alpha=0.50))


# 'Degree', fontsize=16, fontweight='bold'
# Show plot
plt.tight_layout()
plt.savefig("Log2_Fold_change_vs_Hub_Names.png", dpi=500)
plt.show()

# %%
joined_df
# Out:
#    Name (Yellow hubs)  Degree  BetweennessCentrality gene_name  Mean_log2FC
# 0               Stat1      40               0.460312     Stat1     2.933736
# 1                Irf7      21               0.063256      Irf7     2.283998
# 2                Irf1      20               0.092895      Irf1     3.893480
# 3              Cxcl10      18               0.057905    Cxcl10     4.012487
# 4               Isg15      18               0.068774     Isg15     2.985464
# ..                ...     ...                    ...       ...          ...
# 73              Tgtp1       1               0.000000     Tgtp1     4.849469
# 74              Erap1       1               0.000000     Erap1     1.599159
# 75            Gm11562       1               0.000000   Gm11562     1.877261
# 76           Krtap2-4       1               0.000000  Krtap2-4     1.766494
# 77             Gm5431       1               0.000000    Gm5431     1.298088
#
# [78 rows x 5 columns]

# %%
pip install powerlaw
# Out:
# Requirement already satisfied: powerlaw in /usr/local/lib/python3.10/dist-packages (1.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from powerlaw) (1.11.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from powerlaw) (1.25.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from powerlaw) (3.7.1)
# Requirement already satisfied: mpmath in /usr/local/lib/python3.10/dist-packages (from powerlaw) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->powerlaw) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->powerlaw) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->powerlaw) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->powerlaw) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->powerlaw) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->powerlaw) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->powerlaw) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->powerlaw) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->powerlaw) (1.16.0)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as stats
import powerlaw

# Extract the 'Degree' column from joined_df
degree_data = joined_df['Degree']
sns.axes_style("ticks")
# Calculate KDE for Degree
sns.histplot(degree_data, kde=True, color='blue', linewidth=1, alpha=0.2)
plt.xlabel('Degree', fontsize=16, fontweight='bold')
plt.ylabel('Frequency', fontsize=16, fontweight='bold')
plt.tick_params(axis='both', labelsize=16)

# Display statistics
plt.title('Power Law of Degree Distribution', fontsize=16)

# Fit a power-law distribution to the data
fit = powerlaw.Fit(degree_data)

# Get the exponent of the power-law fit
exponent = fit.alpha

# Get R^2 and p-value
R2, p_value = fit.distribution_compare('power_law', 'exponential', normalized_ratio=True)

# Display KS Score, exponent of power law fit, R^2, and p-value
plt.text(0.7, 0.8, f"\nKS Score: {fit.D:.2f}\nExponent: {exponent:.2f}\nR$^2$: {R2:.2f}\np-value: {p_value:.4f}",
         ha='left', va='center', transform=plt.gca().transAxes, fontsize=12, color='black')



plt.tight_layout()
plt.savefig("Power_Law_of_Degree_Distribution.png", dpi=500)
# plt.grid(False)
plt.show()
# Out:
# Calculating best minimal value for power law fit
# xmin progress: 94%

# %%
import numpy as np
import powerlaw

# Assuming you have a NumPy array or list of degree values called 'degree_data'
# Fit a power-law distribution to the degree sequence
fit = powerlaw.Fit(degree_data)
# Out:
# Calculating best minimal value for power law fit
# xmin progress: 94%

# %%
degree_data.value_counts()
# Out:
# Degree
# 1     14
# 2      9
# 6      7
# 5      6
# 7      6
# 9      5
# 3      4
# 4      4
# 10     4
# 8      3
# 14     3
# 12     2
# 13     2
# 15     2
# 18     2
# 11     1
# 21     1
# 17     1
# 20     1
# 40     1
# Name: count, dtype: int64

# %%
import powerlaw

# Assuming you have a NumPy array or list of degree values called 'degree_data'
# Fit a power-law distribution to the degree sequence
fit = powerlaw.Fit(degree_data)

# Calculate the p-value using the Kolmogorov-Smirnov test
p_value = fit.distribution_compare('power_law', 'lognormal', normalized_ratio=True)[1]

# Print details of the power-law fit
print("Power-law fit details:")
print(f"Alpha (exponent): {fit.alpha:.2f}")
print(f"Xmin (cutoff value): {fit.xmin}")
print(f"KS test statistic: {fit.D:.2f}")
print(f"P-value: {p_value:.4f}")
print(f"R-squared value: {fit.r_squared:.2f}")
# Out:
# Calculating best minimal value for power law fit
# Power-law fit details:
# Alpha (exponent): 4.76
# Xmin (cutoff value): 13.0
# KS test statistic: 0.10
# P-value: 0.2502
# /usr/local/lib/python3.10/dist-packages/powerlaw.py:1507: RuntimeWarning: overflow encountered in divide
#   likelihoods = f/C
# /usr/local/lib/python3.10/dist-packages/powerlaw.py:1615: RuntimeWarning: invalid value encountered in divide
#   CDF = CDF/norm
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-1ab6ec814476> in <cell line: 16>()
#      14 print(f"KS test statistic: {fit.D:.2f}")
#      15 print(f"P-value: {p_value:.4f}")
# ---> 16 print(f"R-squared value: {fit.r_squared:.2f}")
#
# /usr/local/lib/python3.10/dist-packages/powerlaw.py in __getattr__(self, name)
#     177             return getattr(self, name)
#     178         else:
# --> 179             raise AttributeError(name)
#     180
#     181     def find_xmin(self, xmin_distance=None):
#
# AttributeError: r_squared

# %%
import powerlaw

# Assuming degree_data is your series/data
# Replace this with your actual data
degree_data = np.array(degree_data)

fit = powerlaw.Fit(degree_data)

# Print the parameters
print("Alpha (exponent of the power-law distribution):", fit.alpha)
print("Xmin (the lower bound of the power-law distribution):", fit.xmin)

# Calculate the log-likelihood ratio
loglikelihood_ratio = fit.distribution_compare('power_law', 'exponential')
print("Log-likelihood ratio (power law vs. exponential):", loglikelihood_ratio)

# Calculate the p-value
p_value = fit.distribution_compare('power_law', 'exponential', normalized_ratio=True)[1]
print("p-value:", p_value)
# Out:
# Calculating best minimal value for power law fit
# Alpha (exponent of the power-law distribution): 4.755141130271971
# Xmin (the lower bound of the power-law distribution): 13.0
# Log-likelihood ratio (power law vs. exponential): (0.9107839993201452, 0.31831406731240697)
# p-value: 0.31831406731240697

# %%
pip install igraph
# Out:
# Collecting igraph
#   Downloading igraph-0.11.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 13.6 MB/s eta 0:00:00
# Collecting texttable>=1.6.2 (from igraph)
#   Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Installing collected packages: texttable, igraph
# Successfully installed igraph-0.11.4 texttable-1.7.0

# %%
from igraph import Graph
import numpy as np
import pandas as pd

# Set up an empty list to store details for each network
network_details = []

# Use a for loop to repeat 1000 times
for i in range(1000):
    # Generate a random network using the Erdos-Renyi model
    g = Graph.Erdos_Renyi(n=78, m=275, directed=False)

    # Calculate clustering coefficient of this network
    cc = g.transitivity_undirected()

    # Calculate the average shortest path length of this network
    aspl = g.average_path_length()

    # Store details for this network in a dictionary
    network_details.append({
        "Network": i + 1,
        "Clustering Coefficient": cc,
        "Average Shortest Path Length": aspl
    })

    # Print results
    print("Network:", i + 1)
    print("Clustering Coefficient:", cc)
    print("Average Shortest Path Length:", aspl)

# Create a DataFrame from the list of dictionaries
df = pd.DataFrame(network_details)

# Calculate mean values
cc_mean = df["Clustering Coefficient"].mean()
aspl_mean = df["Average Shortest Path Length"].mean()

print("Mean Clustering Coefficient:", cc_mean)
print("Mean Average Shortest Path Length:", aspl_mean)

# Write DataFrame to a CSV file
# df.to_csv("random_network_details.csv", index=False)

df
# Out:
# Network: 1
# Clustering Coefficient: 0.08714362560516406
# Average Shortest Path Length: 2.425907425907426
# Network: 2
# Clustering Coefficient: 0.08337622233659289
# Average Shortest Path Length: 2.4019314019314018
# Network: 3
# Clustering Coefficient: 0.10066090493136756
# Average Shortest Path Length: 2.40992340992341
# Network: 4
# Clustering Coefficient: 0.0989724175229854
# Average Shortest Path Length: 2.415917415917416
# Network: 5
# Clustering Coefficient: 0.10276073619631902
# Average Shortest Path Length: 2.4053315105946687
# Network: 6
# Clustering Coefficient: 0.06962025316455696
# Average Shortest Path Length: 2.3940533151059467
# Network: 7
# Clustering Coefficient: 0.08034279592929834
# Average Shortest Path Length: 2.3976023976023977
# Network: 8
# Clustering Coefficient: 0.09838546922300706
# Average Shortest Path Length: 2.4249084249084247
# Network: 9
# Clustering Coefficient: 0.07543216343635412
# Average Shortest Path Length: 2.4082584082584084
# Network: 10
# Clustering Coefficient: 0.07268041237113403
# Average Shortest Path Length: 2.4045954045954048
# Network: 11
# Clustering Coefficient: 0.07950243374797188
# Average Shortest Path Length: 2.4312354312354314
# Network: 12
# Clustering Coefficient: 0.08406850025947069
# Average Shortest Path Length: 2.444222444222444
# Network: 13
# Clustering Coefficient: 0.06937307297019528
# Average Shortest Path Length: 2.422244422244422
# Network: 14
# Clustering Coefficient: 0.11514522821576763
# Average Shortest Path Length: 2.427239427239427
# Network: 15
# Clustering Coefficient: 0.09594882729211088
# Average Shortest Path Length: 2.4295704295704295
# Network: 16
# Clustering Coefficient: 0.09008042895442359
# Average Shortest Path Length: 2.4175824175824174
# Network: 17
# Clustering Coefficient: 0.10561056105610561
# Average Shortest Path Length: 2.4292374292374292
# Network: 18
# Clustering Coefficient: 0.08004268943436499
# Average Shortest Path Length: 2.4155844155844157
# Network: 19
# Clustering Coefficient: 0.0776955602536998
# Average Shortest Path Length: 2.3820915926179085
# Network: 20
# Clustering Coefficient: 0.07982969664715274
# Average Shortest Path Length: 2.4215784215784217
# Network: 21
# Clustering Coefficient: 0.10528992878942015
# Average Shortest Path Length: 2.411255411255411
# Network: 22
# Clustering Coefficient: 0.08397365532381998
# Average Shortest Path Length: 2.391941391941392
# Network: 23
# Clustering Coefficient: 0.09114719748559455
# Average Shortest Path Length: 2.422910422910423
# Network: 24
# Clustering Coefficient: 0.08900255754475703
# Average Shortest Path Length: 2.4122544122544123
# Network: 25
# Clustering Coefficient: 0.09767441860465116
# Average Shortest Path Length: 2.4425574425574426
# Network: 26
# Clustering Coefficient: 0.09172377438060095
# Average Shortest Path Length: 2.4095904095904097
# Network: 27
# Clustering Coefficient: 0.09319764327798608
# Average Shortest Path Length: 2.4189144189144187
# Network: 28
# Clustering Coefficient: 0.08103813559322035
# Average Shortest Path Length: 2.427239427239427
# Network: 29
# Clustering Coefficient: 0.07211538461538461
# Average Shortest Path Length: 2.4012654012654013
# Network: 30
# Clustering Coefficient: 0.096723044397463
# Average Shortest Path Length: 2.4072594072594073
# Network: 31
# Clustering Coefficient: 0.07660239708181345
# Average Shortest Path Length: 2.405927405927406
# Network: 32
# Clustering Coefficient: 0.10926118626430802
# Average Shortest Path Length: 2.4485514485514486
# Network: 33
# Clustering Coefficient: 0.07704654895666131
# Average Shortest Path Length: 2.4155844155844157
# Network: 34
# Clustering Coefficient: 0.1024
# Average Shortest Path Length: 2.4515484515484514
# Network: 35
# Clustering Coefficient: 0.07731958762886598
# Average Shortest Path Length: 2.405261405261405
# Network: 36
# Clustering Coefficient: 0.07894736842105263
# Average Shortest Path Length: 2.404262404262404
# Network: 37
# Clustering Coefficient: 0.0824524312896406
# Average Shortest Path Length: 2.4145854145854146
# Network: 38
# Clustering Coefficient: 0.1032325338894682
# Average Shortest Path Length: 2.4362304362304363
# Network: 39
# Clustering Coefficient: 0.1047065044949762
# Average Shortest Path Length: 2.402930402930403
# Network: 40
# Clustering Coefficient: 0.10686628807434176
# Average Shortest Path Length: 2.431901431901432
# Network: 41
# Clustering Coefficient: 0.08493589743589744
# Average Shortest Path Length: 2.411255411255411
# Network: 42
# Clustering Coefficient: 0.07131537242472266
# Average Shortest Path Length: 2.413919413919414
# Network: 43
# Clustering Coefficient: 0.09984152139461172
# Average Shortest Path Length: 2.4185814185814185
# Network: 44
# Clustering Coefficient: 0.12244897959183673
# Average Shortest Path Length: 2.4492174492174494
# Network: 45
# Clustering Coefficient: 0.10872894333843798
# Average Shortest Path Length: 2.439227439227439
# Network: 46
# Clustering Coefficient: 0.09770421783235451
# Average Shortest Path Length: 2.4265734265734267
# Network: 47
# Clustering Coefficient: 0.1047065044949762
# Average Shortest Path Length: 2.4425574425574426
# Network: 48
# Clustering Coefficient: 0.0748853795211411
# Average Shortest Path Length: 2.417249417249417
# Network: 49
# Clustering Coefficient: 0.10944206008583691
# Average Shortest Path Length: 2.434232434232434
# Network: 50
# Clustering Coefficient: 0.08962264150943396
# Average Shortest Path Length: 2.4082584082584084
# Network: 51
# Clustering Coefficient: 0.07285483000539665
# Average Shortest Path Length: 2.4182484182484183
# Network: 52
# Clustering Coefficient: 0.09536637931034483
# Average Shortest Path Length: 2.421245421245421
# Network: 53
# Clustering Coefficient: 0.10697179350718468
# Average Shortest Path Length: 2.4435564435564436
# Network: 54
# Clustering Coefficient: 0.10403726708074534
# Average Shortest Path Length: 2.4352314352314353
# Network: 55
# Clustering Coefficient: 0.09713375796178345
# Average Shortest Path Length: 2.4242424242424243
# Network: 56
# Clustering Coefficient: 0.091995841995842
# Average Shortest Path Length: 2.4405594405594404
# Network: 57
# Clustering Coefficient: 0.084375
# Average Shortest Path Length: 2.415251415251415
# Network: 58
# Clustering Coefficient: 0.12603734439834025
# Average Shortest Path Length: 2.407723855092276
# Network: 59
# Clustering Coefficient: 0.09137055837563451
# Average Shortest Path Length: 2.416916416916417
# Network: 60
# Clustering Coefficient: 0.07823310271420969
# Average Shortest Path Length: 2.4155844155844157
# Network: 61
# Clustering Coefficient: 0.08342420937840785
# Average Shortest Path Length: 2.4085914085914086
# Network: 62
# Clustering Coefficient: 0.09071949947862357
# Average Shortest Path Length: 2.4255744255744256
# Network: 63
# Clustering Coefficient: 0.08501362397820164
# Average Shortest Path Length: 2.404928404928405
# Network: 64
# Clustering Coefficient: 0.11026033690658499
# Average Shortest Path Length: 2.4202464202464204
# Network: 65
# Clustering Coefficient: 0.08931419457735247
# Average Shortest Path Length: 2.41991341991342
# Network: 66
# Clustering Coefficient: 0.08070356958096224
# Average Shortest Path Length: 2.399267399267399
# Network: 67
# Clustering Coefficient: 0.09957850368809273
# Average Shortest Path Length: 2.4375624375624376
# Network: 68
# Clustering Coefficient: 0.09278350515463918
# Average Shortest Path Length: 2.4232434232434232
# Network: 69
# Clustering Coefficient: 0.10139484978540772
# Average Shortest Path Length: 2.4358974358974357
# Network: 70
# Clustering Coefficient: 0.07869884575026233
# Average Shortest Path Length: 2.4005994005994005
# Network: 71
# Clustering Coefficient: 0.09115138592750532
# Average Shortest Path Length: 2.416583416583417
# Network: 72
# Clustering Coefficient: 0.07820646506777894
# Average Shortest Path Length: 2.4565434565434567
# Network: 73
# Clustering Coefficient: 0.08842443729903537
# Average Shortest Path Length: 2.4202464202464204
# Network: 74
# Clustering Coefficient: 0.0989888238424694
# Average Shortest Path Length: 2.416583416583417
# Network: 75
# Clustering Coefficient: 0.0754414125200642
# Average Shortest Path Length: 2.404262404262404
# Network: 76
# Clustering Coefficient: 0.09556135770234987
# Average Shortest Path Length: 2.4368964368964368
# Network: 77
# Clustering Coefficient: 0.07397691500524659
# Average Shortest Path Length: 2.4132534132534134
# Network: 78
# Clustering Coefficient: 0.08427876823338736
# Average Shortest Path Length: 2.410922410922411
# Network: 79
# Clustering Coefficient: 0.11229135053110774
# Average Shortest Path Length: 2.440892440892441
# Network: 80
# Clustering Coefficient: 0.1126984126984127
# Average Shortest Path Length: 2.4142524142524144
# Network: 81
# Clustering Coefficient: 0.09043659043659044
# Average Shortest Path Length: 2.428238428238428
# Network: 82
# Clustering Coefficient: 0.0851063829787234
# Average Shortest Path Length: 2.427905427905428
# Network: 83
# Clustering Coefficient: 0.08823529411764706
# Average Shortest Path Length: 2.4155844155844157
# Network: 84
# Clustering Coefficient: 0.09316770186335403
# Average Shortest Path Length: 2.4015984015984015
# Network: 85
# Clustering Coefficient: 0.09448818897637795
# Average Shortest Path Length: 2.4189144189144187
# Network: 86
# Clustering Coefficient: 0.09198493813878429
# Average Shortest Path Length: 2.4232434232434232
# Network: 87
# Clustering Coefficient: 0.07094062007356805
# Average Shortest Path Length: 2.40992340992341
# Network: 88
# Clustering Coefficient: 0.09636650868878358
# Average Shortest Path Length: 2.4215784215784217
# Network: 89
# Clustering Coefficient: 0.08236536430834214
# Average Shortest Path Length: 2.4205794205794207
# Network: 90
# Clustering Coefficient: 0.08814270724029381
# Average Shortest Path Length: 2.428904428904429
# Network: 91
# Clustering Coefficient: 0.07448494453248812
# Average Shortest Path Length: 2.3986013986013988
# Network: 92
# Clustering Coefficient: 0.07676240208877284
# Average Shortest Path Length: 2.3952713952713953
# Network: 93
# Clustering Coefficient: 0.07419354838709677
# Average Shortest Path Length: 2.4249084249084247
# Network: 94
# Clustering Coefficient: 0.07765451664025357
# Average Shortest Path Length: 2.4145854145854146
# Network: 95
# Clustering Coefficient: 0.08125331917153479
# Average Shortest Path Length: 2.4285714285714284
# Network: 96
# Clustering Coefficient: 0.09201480698043363
# Average Shortest Path Length: 2.4055944055944054
# Network: 97
# Clustering Coefficient: 0.11070110701107011
# Average Shortest Path Length: 2.451881451881452
# Network: 98
# Clustering Coefficient: 0.0870712401055409
# Average Shortest Path Length: 2.432900432900433
# Network: 99
# Clustering Coefficient: 0.09071949947862357
# Average Shortest Path Length: 2.451215451215451
# Network: 100
# Clustering Coefficient: 0.08206207259337191
# Average Shortest Path Length: 2.4155844155844157
# Network: 101
# Clustering Coefficient: 0.08403805496828752
# Average Shortest Path Length: 2.4242424242424243
# Network: 102
# Clustering Coefficient: 0.09095661265028751
# Average Shortest Path Length: 2.4292374292374292
# Network: 103
# Clustering Coefficient: 0.09742268041237113
# Average Shortest Path Length: 2.398838004101162
# Network: 104
# Clustering Coefficient: 0.10089332632685234
# Average Shortest Path Length: 2.413192071086808
# Network: 105
# Clustering Coefficient: 0.0836461126005362
# Average Shortest Path Length: 2.416916416916417
# Network: 106
# Clustering Coefficient: 0.08800823468862584
# Average Shortest Path Length: 2.4202464202464204
# Network: 107
# Clustering Coefficient: 0.09601259181532004
# Average Shortest Path Length: 2.411921411921412
# Network: 108
# Clustering Coefficient: 0.08688783570300158
# Average Shortest Path Length: 2.416583416583417
# Network: 109
# Clustering Coefficient: 0.08048395581273014
# Average Shortest Path Length: 2.4195804195804196
# Network: 110
# Clustering Coefficient: 0.09848484848484848
# Average Shortest Path Length: 2.4435564435564436
# Network: 111
# Clustering Coefficient: 0.09656992084432718
# Average Shortest Path Length: 2.411921411921412
# Network: 112
# Clustering Coefficient: 0.08791208791208792
# Average Shortest Path Length: 2.420912420912421
# Network: 113
# Clustering Coefficient: 0.09596224436287362
# Average Shortest Path Length: 2.416583416583417
# Network: 114
# Clustering Coefficient: 0.09052408681842244
# Average Shortest Path Length: 2.4056732740943265
# Network: 115
# Clustering Coefficient: 0.09554140127388536
# Average Shortest Path Length: 2.415251415251415
# Network: 116
# Clustering Coefficient: 0.09782608695652174
# Average Shortest Path Length: 2.427905427905428
# Network: 117
# Clustering Coefficient: 0.10052356020942409
# Average Shortest Path Length: 2.452880452880453
# Network: 118
# Clustering Coefficient: 0.11297071129707113
# Average Shortest Path Length: 2.4505494505494507
# Network: 119
# Clustering Coefficient: 0.09581151832460733
# Average Shortest Path Length: 2.4182484182484183
# Network: 120
# Clustering Coefficient: 0.05954935622317597
# Average Shortest Path Length: 2.4192474192474194
# Network: 121
# Clustering Coefficient: 0.08892355694227769
# Average Shortest Path Length: 2.4505494505494507
# Network: 122
# Clustering Coefficient: 0.07532051282051282
# Average Shortest Path Length: 2.398268398268398
# Network: 123
# Clustering Coefficient: 0.09602478058853897
# Average Shortest Path Length: 2.4122544122544123
# Network: 124
# Clustering Coefficient: 0.10561224489795919
# Average Shortest Path Length: 2.417915417915418
# Network: 125
# Clustering Coefficient: 0.07911733046286329
# Average Shortest Path Length: 2.409257409257409
# Network: 126
# Clustering Coefficient: 0.0873634945397816
# Average Shortest Path Length: 2.431901431901432
# Network: 127
# Clustering Coefficient: 0.09722222222222222
# Average Shortest Path Length: 2.4435564435564436
# Network: 128
# Clustering Coefficient: 0.09404388714733543
# Average Shortest Path Length: 2.417249417249417
# Network: 129
# Clustering Coefficient: 0.09513742071881606
# Average Shortest Path Length: 2.420912420912421
# Network: 130
# Clustering Coefficient: 0.058409951325040566
# Average Shortest Path Length: 2.410589410589411
# Network: 131
# Clustering Coefficient: 0.10117773019271949
# Average Shortest Path Length: 2.422910422910423
# Network: 132
# Clustering Coefficient: 0.09486780715396578
# Average Shortest Path Length: 2.4195804195804196
# Network: 133
# Clustering Coefficient: 0.07413249211356467
# Average Shortest Path Length: 2.4215784215784217
# Network: 134
# Clustering Coefficient: 0.10221992772328342
# Average Shortest Path Length: 2.405261405261405
# Network: 135
# Clustering Coefficient: 0.08652333508127949
# Average Shortest Path Length: 2.408924408924409
# Network: 136
# Clustering Coefficient: 0.09615384615384616
# Average Shortest Path Length: 2.4362304362304363
# Network: 137
# Clustering Coefficient: 0.1076923076923077
# Average Shortest Path Length: 2.4305694305694305
# Network: 138
# Clustering Coefficient: 0.09531502423263329
# Average Shortest Path Length: 2.4255744255744256
# Network: 139
# Clustering Coefficient: 0.0768392370572207
# Average Shortest Path Length: 2.410922410922411
# Network: 140
# Clustering Coefficient: 0.10770855332629356
# Average Shortest Path Length: 2.439227439227439
# Network: 141
# Clustering Coefficient: 0.0937980522808816
# Average Shortest Path Length: 2.4185814185814185
# Network: 142
# Clustering Coefficient: 0.0984647961884595
# Average Shortest Path Length: 2.428238428238428
# Network: 143
# Clustering Coefficient: 0.10985043837029397
# Average Shortest Path Length: 2.4039644565960354
# Network: 144
# Clustering Coefficient: 0.11092985318107668
# Average Shortest Path Length: 2.4305694305694305
# Network: 145
# Clustering Coefficient: 0.08945686900958466
# Average Shortest Path Length: 2.41025641025641
# Network: 146
# Clustering Coefficient: 0.08138297872340426
# Average Shortest Path Length: 2.411255411255411
# Network: 147
# Clustering Coefficient: 0.08704663212435233
# Average Shortest Path Length: 2.3902763902763904
# Network: 148
# Clustering Coefficient: 0.08087091757387248
# Average Shortest Path Length: 2.3952713952713953
# Network: 149
# Clustering Coefficient: 0.07250268528464017
# Average Shortest Path Length: 2.403929403929404
# Network: 150
# Clustering Coefficient: 0.09608540925266904
# Average Shortest Path Length: 2.417915417915418
# Network: 151
# Clustering Coefficient: 0.0707395498392283
# Average Shortest Path Length: 2.3956043956043955
# Network: 152
# Clustering Coefficient: 0.08765743073047859
# Average Shortest Path Length: 2.3916083916083917
# Network: 153
# Clustering Coefficient: 0.08035714285714286
# Average Shortest Path Length: 2.4019314019314018
# Network: 154
# Clustering Coefficient: 0.08174386920980926
# Average Shortest Path Length: 2.404928404928405
# Network: 155
# Clustering Coefficient: 0.09201480698043363
# Average Shortest Path Length: 2.4302364302364303
# Network: 156
# Clustering Coefficient: 0.07970244420828905
# Average Shortest Path Length: 2.4145854145854146
# Network: 157
# Clustering Coefficient: 0.07492029755579172
# Average Shortest Path Length: 2.4368964368964368
# Network: 158
# Clustering Coefficient: 0.09036144578313253
# Average Shortest Path Length: 2.4315684315684316
# Network: 159
# Clustering Coefficient: 0.0946372239747634
# Average Shortest Path Length: 2.4225774225774224
# Network: 160
# Clustering Coefficient: 0.0912906610703043
# Average Shortest Path Length: 2.389952153110048
# Network: 161
# Clustering Coefficient: 0.09936908517350158
# Average Shortest Path Length: 2.4115884115884114
# Network: 162
# Clustering Coefficient: 0.11764705882352941
# Average Shortest Path Length: 2.4472194472194473
# Network: 163
# Clustering Coefficient: 0.09957850368809273
# Average Shortest Path Length: 2.433899433899434
# Network: 164
# Clustering Coefficient: 0.08875739644970414
# Average Shortest Path Length: 2.417915417915418
# Network: 165
# Clustering Coefficient: 0.08259911894273128
# Average Shortest Path Length: 2.405261405261405
# Network: 166
# Clustering Coefficient: 0.09799789251844046
# Average Shortest Path Length: 2.4262404262404265
# Network: 167
# Clustering Coefficient: 0.10903426791277258
# Average Shortest Path Length: 2.4255744255744256
# Network: 168
# Clustering Coefficient: 0.10534351145038168
# Average Shortest Path Length: 2.4242424242424243
# Network: 169
# Clustering Coefficient: 0.09628120224146715
# Average Shortest Path Length: 2.3684210526315788
# Network: 170
# Clustering Coefficient: 0.09571129707112971
# Average Shortest Path Length: 2.422244422244422
# Network: 171
# Clustering Coefficient: 0.0839493136219641
# Average Shortest Path Length: 2.41025641025641
# Network: 172
# Clustering Coefficient: 0.09796573875802998
# Average Shortest Path Length: 2.431901431901432
# Network: 173
# Clustering Coefficient: 0.09379885356956748
# Average Shortest Path Length: 2.4175824175824174
# Network: 174
# Clustering Coefficient: 0.10424118548799183
# Average Shortest Path Length: 2.425907425907426
# Network: 175
# Clustering Coefficient: 0.09052408681842244
# Average Shortest Path Length: 2.4305694305694305
# Network: 176
# Clustering Coefficient: 0.09163987138263666
# Average Shortest Path Length: 2.450882450882451
# Network: 177
# Clustering Coefficient: 0.09090909090909091
# Average Shortest Path Length: 2.423909423909424
# Network: 178
# Clustering Coefficient: 0.08421610169491525
# Average Shortest Path Length: 2.4482184482184484
# Network: 179
# Clustering Coefficient: 0.08842794759825327
# Average Shortest Path Length: 2.420912420912421
# Network: 180
# Clustering Coefficient: 0.09498680738786279
# Average Shortest Path Length: 2.420912420912421
# Network: 181
# Clustering Coefficient: 0.10140405616224649
# Average Shortest Path Length: 2.4352314352314353
# Network: 182
# Clustering Coefficient: 0.09503695881731784
# Average Shortest Path Length: 2.40992340992341
# Network: 183
# Clustering Coefficient: 0.09414893617021276
# Average Shortest Path Length: 2.417249417249417
# Network: 184
# Clustering Coefficient: 0.07576571735626007
# Average Shortest Path Length: 2.4065934065934065
# Network: 185
# Clustering Coefficient: 0.081419624217119
# Average Shortest Path Length: 2.4070403280929598
# Network: 186
# Clustering Coefficient: 0.09399075500770417
# Average Shortest Path Length: 2.400546821599453
# Network: 187
# Clustering Coefficient: 0.09223300970873786
# Average Shortest Path Length: 2.410922410922411
# Network: 188
# Clustering Coefficient: 0.08455284552845528
# Average Shortest Path Length: 2.411921411921412
# Network: 189
# Clustering Coefficient: 0.08004268943436499
# Average Shortest Path Length: 2.399267399267399
# Network: 190
# Clustering Coefficient: 0.10835913312693499
# Average Shortest Path Length: 2.417249417249417
# Network: 191
# Clustering Coefficient: 0.0996309963099631
# Average Shortest Path Length: 2.4305694305694305
# Network: 192
# Clustering Coefficient: 0.08665966386554622
# Average Shortest Path Length: 2.4235764235764234
# Network: 193
# Clustering Coefficient: 0.09183673469387756
# Average Shortest Path Length: 2.4352314352314353
# Network: 194
# Clustering Coefficient: 0.08155650319829424
# Average Shortest Path Length: 2.4125874125874125
# Network: 195
# Clustering Coefficient: 0.08691153647180548
# Average Shortest Path Length: 2.4155844155844157
# Network: 196
# Clustering Coefficient: 0.0954118873826903
# Average Shortest Path Length: 2.404262404262404
# Network: 197
# Clustering Coefficient: 0.09
# Average Shortest Path Length: 2.40123034859877
# Network: 198
# Clustering Coefficient: 0.10531750129065565
# Average Shortest Path Length: 2.420912420912421
# Network: 199
# Clustering Coefficient: 0.08289885297184567
# Average Shortest Path Length: 2.423909423909424
# Network: 200
# Clustering Coefficient: 0.09453781512605042
# Average Shortest Path Length: 2.3976023976023977
# Network: 201
# Clustering Coefficient: 0.0964172813487882
# Average Shortest Path Length: 2.4235764235764234
# Network: 202
# Clustering Coefficient: 0.09916054564533054
# Average Shortest Path Length: 2.43989343989344
# Network: 203
# Clustering Coefficient: 0.0899390243902439
# Average Shortest Path Length: 2.4132534132534134
# Network: 204
# Clustering Coefficient: 0.0861169102296451
# Average Shortest Path Length: 2.425907425907426
# Network: 205
# Clustering Coefficient: 0.08991825613079019
# Average Shortest Path Length: 2.4082584082584084
# Network: 206
# Clustering Coefficient: 0.070026525198939
# Average Shortest Path Length: 2.444888444888445
# Network: 207
# Clustering Coefficient: 0.11278195488721804
# Average Shortest Path Length: 2.4192474192474194
# Network: 208
# Clustering Coefficient: 0.09044455799693409
# Average Shortest Path Length: 2.414918414918415
# Network: 209
# Clustering Coefficient: 0.1045958795562599
# Average Shortest Path Length: 2.4242424242424243
# Network: 210
# Clustering Coefficient: 0.08029978586723768
# Average Shortest Path Length: 2.400932400932401
# Network: 211
# Clustering Coefficient: 0.10066090493136756
# Average Shortest Path Length: 2.421245421245421
# Network: 212
# Clustering Coefficient: 0.09020217729393468
# Average Shortest Path Length: 2.416916416916417
# Network: 213
# Clustering Coefficient: 0.09708222811671087
# Average Shortest Path Length: 2.433899433899434
# Network: 214
# Clustering Coefficient: 0.07928118393234672
# Average Shortest Path Length: 2.41991341991342
# Network: 215
# Clustering Coefficient: 0.06825396825396825
# Average Shortest Path Length: 2.426906426906427
# Network: 216
# Clustering Coefficient: 0.09457364341085271
# Average Shortest Path Length: 2.4285714285714284
# Network: 217
# Clustering Coefficient: 0.07981220657276995
# Average Shortest Path Length: 2.4202464202464204
# Network: 218
# Clustering Coefficient: 0.11380880121396054
# Average Shortest Path Length: 2.4375624375624376
# Network: 219
# Clustering Coefficient: 0.0900155199172271
# Average Shortest Path Length: 2.41025641025641
# Network: 220
# Clustering Coefficient: 0.09018987341772151
# Average Shortest Path Length: 2.4142524142524144
# Network: 221
# Clustering Coefficient: 0.07869884575026233
# Average Shortest Path Length: 2.4202464202464204
# Network: 222
# Clustering Coefficient: 0.09602478058853897
# Average Shortest Path Length: 2.4415584415584415
# Network: 223
# Clustering Coefficient: 0.09744408945686901
# Average Shortest Path Length: 2.446220446220446
# Network: 224
# Clustering Coefficient: 0.09569377990430622
# Average Shortest Path Length: 2.4195804195804196
# Network: 225
# Clustering Coefficient: 0.09562982005141388
# Average Shortest Path Length: 2.414918414918415
# Network: 226
# Clustering Coefficient: 0.11749745676500509
# Average Shortest Path Length: 2.4542124542124544
# Network: 227
# Clustering Coefficient: 0.08711721224920803
# Average Shortest Path Length: 2.4432234432234434
# Network: 228
# Clustering Coefficient: 0.09959141981613892
# Average Shortest Path Length: 2.4325674325674327
# Network: 229
# Clustering Coefficient: 0.08268330733229329
# Average Shortest Path Length: 2.4192474192474194
# Network: 230
# Clustering Coefficient: 0.08691153647180548
# Average Shortest Path Length: 2.4062604062604063
# Network: 231
# Clustering Coefficient: 0.09510567296996662
# Average Shortest Path Length: 2.415251415251415
# Network: 232
# Clustering Coefficient: 0.08138903960933261
# Average Shortest Path Length: 2.4135864135864136
# Network: 233
# Clustering Coefficient: 0.07865757734661773
# Average Shortest Path Length: 2.404928404928405
# Network: 234
# Clustering Coefficient: 0.09818731117824774
# Average Shortest Path Length: 2.4355644355644355
# Network: 235
# Clustering Coefficient: 0.09581151832460733
# Average Shortest Path Length: 2.414918414918415
# Network: 236
# Clustering Coefficient: 0.09211222869242985
# Average Shortest Path Length: 2.445221445221445
# Network: 237
# Clustering Coefficient: 0.09508716323296355
# Average Shortest Path Length: 2.3999333999334
# Network: 238
# Clustering Coefficient: 0.08173076923076923
# Average Shortest Path Length: 2.4142524142524144
# Network: 239
# Clustering Coefficient: 0.10082730093071354
# Average Shortest Path Length: 2.4365634365634365
# Network: 240
# Clustering Coefficient: 0.079155672823219
# Average Shortest Path Length: 2.4115884115884114
# Network: 241
# Clustering Coefficient: 0.09495708154506438
# Average Shortest Path Length: 2.405927405927406
# Network: 242
# Clustering Coefficient: 0.07845188284518828
# Average Shortest Path Length: 2.4082584082584084
# Network: 243
# Clustering Coefficient: 0.10730948678071539
# Average Shortest Path Length: 2.4455544455544453
# Network: 244
# Clustering Coefficient: 0.09163987138263666
# Average Shortest Path Length: 2.4025974025974026
# Network: 245
# Clustering Coefficient: 0.07755946225439504
# Average Shortest Path Length: 2.4075924075924076
# Network: 246
# Clustering Coefficient: 0.10941350418925579
# Average Shortest Path Length: 2.4079254079254078
# Network: 247
# Clustering Coefficient: 0.09071618037135279
# Average Shortest Path Length: 2.422244422244422
# Network: 248
# Clustering Coefficient: 0.09848879624804585
# Average Shortest Path Length: 2.448884448884449
# Network: 249
# Clustering Coefficient: 0.08957654723127036
# Average Shortest Path Length: 2.416916416916417
# Network: 250
# Clustering Coefficient: 0.07566999474513926
# Average Shortest Path Length: 2.428904428904429
# Network: 251
# Clustering Coefficient: 0.08368421052631579
# Average Shortest Path Length: 2.433233433233433
# Network: 252
# Clustering Coefficient: 0.07940709370037057
# Average Shortest Path Length: 2.4129204129204127
# Network: 253
# Clustering Coefficient: 0.09442724458204334
# Average Shortest Path Length: 2.440892440892441
# Network: 254
# Clustering Coefficient: 0.07894736842105263
# Average Shortest Path Length: 2.4255744255744256
# Network: 255
# Clustering Coefficient: 0.09321595028482652
# Average Shortest Path Length: 2.416583416583417
# Network: 256
# Clustering Coefficient: 0.09085992428339643
# Average Shortest Path Length: 2.4235764235764234
# Network: 257
# Clustering Coefficient: 0.10010266940451745
# Average Shortest Path Length: 2.4385614385614387
# Network: 258
# Clustering Coefficient: 0.09746192893401015
# Average Shortest Path Length: 2.4202464202464204
# Network: 259
# Clustering Coefficient: 0.1024314536989136
# Average Shortest Path Length: 2.4242424242424243
# Network: 260
# Clustering Coefficient: 0.07116499736425935
# Average Shortest Path Length: 2.394938394938395
# Network: 261
# Clustering Coefficient: 0.09994794377928162
# Average Shortest Path Length: 2.410922410922411
# Network: 262
# Clustering Coefficient: 0.08603292618162507
# Average Shortest Path Length: 2.409257409257409
# Network: 263
# Clustering Coefficient: 0.0816
# Average Shortest Path Length: 2.4295704295704295
# Network: 264
# Clustering Coefficient: 0.07643312101910828
# Average Shortest Path Length: 2.403929403929404
# Network: 265
# Clustering Coefficient: 0.0790722192936215
# Average Shortest Path Length: 2.4192474192474194
# Network: 266
# Clustering Coefficient: 0.09728033472803348
# Average Shortest Path Length: 2.427905427905428
# Network: 267
# Clustering Coefficient: 0.08823529411764706
# Average Shortest Path Length: 2.40992340992341
# Network: 268
# Clustering Coefficient: 0.09702660406885759
# Average Shortest Path Length: 2.4142524142524144
# Network: 269
# Clustering Coefficient: 0.08129233976029182
# Average Shortest Path Length: 2.410922410922411
# Network: 270
# Clustering Coefficient: 0.0778816199376947
# Average Shortest Path Length: 2.445887445887446
# Network: 271
# Clustering Coefficient: 0.09686888454011741
# Average Shortest Path Length: 2.4145854145854146
# Network: 272
# Clustering Coefficient: 0.09804955192409066
# Average Shortest Path Length: 2.4305694305694305
# Network: 273
# Clustering Coefficient: 0.07610993657505286
# Average Shortest Path Length: 2.4135864135864136
# Network: 274
# Clustering Coefficient: 0.10504634397528322
# Average Shortest Path Length: 2.448884448884449
# Network: 275
# Clustering Coefficient: 0.08575966119640022
# Average Shortest Path Length: 2.4365634365634365
# Network: 276
# Clustering Coefficient: 0.08455114822546973
# Average Shortest Path Length: 2.4075924075924076
# Network: 277
# Clustering Coefficient: 0.0892018779342723
# Average Shortest Path Length: 2.4155844155844157
# Network: 278
# Clustering Coefficient: 0.0840122199592668
# Average Shortest Path Length: 2.42990342990343
# Network: 279
# Clustering Coefficient: 0.09516380655226209
# Average Shortest Path Length: 2.4082584082584084
# Network: 280
# Clustering Coefficient: 0.12874251497005987
# Average Shortest Path Length: 2.422910422910423
# Network: 281
# Clustering Coefficient: 0.11632653061224489
# Average Shortest Path Length: 2.444888444888445
# Network: 282
# Clustering Coefficient: 0.08478260869565217
# Average Shortest Path Length: 2.405927405927406
# Network: 283
# Clustering Coefficient: 0.08945686900958466
# Average Shortest Path Length: 2.415251415251415
# Network: 284
# Clustering Coefficient: 0.10209424083769633
# Average Shortest Path Length: 2.426906426906427
# Network: 285
# Clustering Coefficient: 0.09544008483563096
# Average Shortest Path Length: 2.438894438894439
# Network: 286
# Clustering Coefficient: 0.08950452850293021
# Average Shortest Path Length: 2.4125874125874125
# Network: 287
# Clustering Coefficient: 0.08446298227320125
# Average Shortest Path Length: 2.4079254079254078
# Network: 288
# Clustering Coefficient: 0.07894736842105263
# Average Shortest Path Length: 2.4345654345654344
# Network: 289
# Clustering Coefficient: 0.10209424083769633
# Average Shortest Path Length: 2.4432234432234434
# Network: 290
# Clustering Coefficient: 0.08737864077669903
# Average Shortest Path Length: 2.404262404262404
# Network: 291
# Clustering Coefficient: 0.09682539682539683
# Average Shortest Path Length: 2.4095904095904097
# Network: 292
# Clustering Coefficient: 0.0839493136219641
# Average Shortest Path Length: 2.4189144189144187
# Network: 293
# Clustering Coefficient: 0.08846761453396525
# Average Shortest Path Length: 2.4189144189144187
# Network: 294
# Clustering Coefficient: 0.09201480698043363
# Average Shortest Path Length: 2.409257409257409
# Network: 295
# Clustering Coefficient: 0.09
# Average Shortest Path Length: 2.410922410922411
# Network: 296
# Clustering Coefficient: 0.1054874800213106
# Average Shortest Path Length: 2.4345654345654344
# Network: 297
# Clustering Coefficient: 0.096723044397463
# Average Shortest Path Length: 2.434898434898435
# Network: 298
# Clustering Coefficient: 0.08900255754475703
# Average Shortest Path Length: 2.396936396936397
# Network: 299
# Clustering Coefficient: 0.07364975450081833
# Average Shortest Path Length: 2.417249417249417
# Network: 300
# Clustering Coefficient: 0.09038054968287526
# Average Shortest Path Length: 2.4142524142524144
# Network: 301
# Clustering Coefficient: 0.10339425587467363
# Average Shortest Path Length: 2.409257409257409
# Network: 302
# Clustering Coefficient: 0.10676156583629894
# Average Shortest Path Length: 2.41025641025641
# Network: 303
# Clustering Coefficient: 0.08512874408828167
# Average Shortest Path Length: 2.422910422910423
# Network: 304
# Clustering Coefficient: 0.0826271186440678
# Average Shortest Path Length: 2.3721804511278197
# Network: 305
# Clustering Coefficient: 0.08337703198741479
# Average Shortest Path Length: 2.423909423909424
# Network: 306
# Clustering Coefficient: 0.0891891891891892
# Average Shortest Path Length: 2.4129204129204127
# Network: 307
# Clustering Coefficient: 0.1068062827225131
# Average Shortest Path Length: 2.4295704295704295
# Network: 308
# Clustering Coefficient: 0.08346213292117466
# Average Shortest Path Length: 2.415251415251415
# Network: 309
# Clustering Coefficient: 0.08048395581273014
# Average Shortest Path Length: 2.41025641025641
# Network: 310
# Clustering Coefficient: 0.0970724191063174
# Average Shortest Path Length: 2.397129186602871
# Network: 311
# Clustering Coefficient: 0.07869884575026233
# Average Shortest Path Length: 2.4115884115884114
# Network: 312
# Clustering Coefficient: 0.0842433697347894
# Average Shortest Path Length: 2.3999333999334
# Network: 313
# Clustering Coefficient: 0.10297131147540983
# Average Shortest Path Length: 2.4305694305694305
# Network: 314
# Clustering Coefficient: 0.08725542041248018
# Average Shortest Path Length: 2.403929403929404
# Network: 315
# Clustering Coefficient: 0.09153077327722252
# Average Shortest Path Length: 2.4043062200956937
# Network: 316
# Clustering Coefficient: 0.08234660925726588
# Average Shortest Path Length: 2.402930402930403
# Network: 317
# Clustering Coefficient: 0.08221386351423966
# Average Shortest Path Length: 2.411255411255411
# Network: 318
# Clustering Coefficient: 0.08992248062015504
# Average Shortest Path Length: 2.403263403263403
# Network: 319
# Clustering Coefficient: 0.1035015447991761
# Average Shortest Path Length: 2.41991341991342
# Network: 320
# Clustering Coefficient: 0.10172064777327935
# Average Shortest Path Length: 2.432234432234432
# Network: 321
# Clustering Coefficient: 0.09375
# Average Shortest Path Length: 2.4072594072594073
# Network: 322
# Clustering Coefficient: 0.1109936575052854
# Average Shortest Path Length: 2.4358974358974357
# Network: 323
# Clustering Coefficient: 0.10456176319835982
# Average Shortest Path Length: 2.4525474525474524
# Network: 324
# Clustering Coefficient: 0.08129233976029182
# Average Shortest Path Length: 2.4135864135864136
# Network: 325
# Clustering Coefficient: 0.07933081489476525
# Average Shortest Path Length: 2.4418914418914417
# Network: 326
# Clustering Coefficient: 0.09153077327722252
# Average Shortest Path Length: 2.415917415917416
# Network: 327
# Clustering Coefficient: 0.08359133126934984
# Average Shortest Path Length: 2.410589410589411
# Network: 328
# Clustering Coefficient: 0.08661417322834646
# Average Shortest Path Length: 2.4295704295704295
# Network: 329
# Clustering Coefficient: 0.07578947368421053
# Average Shortest Path Length: 2.428238428238428
# Network: 330
# Clustering Coefficient: 0.10010427528675704
# Average Shortest Path Length: 2.410922410922411
# Network: 331
# Clustering Coefficient: 0.07259337190952131
# Average Shortest Path Length: 2.4135864135864136
# Network: 332
# Clustering Coefficient: 0.08929503916449086
# Average Shortest Path Length: 2.438228438228438
# Network: 333
# Clustering Coefficient: 0.09484956654767976
# Average Shortest Path Length: 2.408924408924409
# Network: 334
# Clustering Coefficient: 0.11514522821576763
# Average Shortest Path Length: 2.437895437895438
# Network: 335
# Clustering Coefficient: 0.08771929824561403
# Average Shortest Path Length: 2.4215784215784217
# Network: 336
# Clustering Coefficient: 0.08814102564102565
# Average Shortest Path Length: 2.428904428904429
# Network: 337
# Clustering Coefficient: 0.10087946197620279
# Average Shortest Path Length: 2.4249084249084247
# Network: 338
# Clustering Coefficient: 0.08855515277058519
# Average Shortest Path Length: 2.417249417249417
# Network: 339
# Clustering Coefficient: 0.08466453674121406
# Average Shortest Path Length: 2.4285714285714284
# Network: 340
# Clustering Coefficient: 0.0816
# Average Shortest Path Length: 2.4022644022644024
# Network: 341
# Clustering Coefficient: 0.09043659043659044
# Average Shortest Path Length: 2.406356801093643
# Network: 342
# Clustering Coefficient: 0.08891159938681656
# Average Shortest Path Length: 2.3967874231032127
# Network: 343
# Clustering Coefficient: 0.0928
# Average Shortest Path Length: 2.4129204129204127
# Network: 344
# Clustering Coefficient: 0.08957569408067051
# Average Shortest Path Length: 2.4395604395604398
# Network: 345
# Clustering Coefficient: 0.08681672025723473
# Average Shortest Path Length: 2.410589410589411
# Network: 346
# Clustering Coefficient: 0.09066808059384941
# Average Shortest Path Length: 2.427905427905428
# Network: 347
# Clustering Coefficient: 0.07970244420828905
# Average Shortest Path Length: 2.4045954045954048
# Network: 348
# Clustering Coefficient: 0.10087946197620279
# Average Shortest Path Length: 2.425907425907426
# Network: 349
# Clustering Coefficient: 0.08372827804107424
# Average Shortest Path Length: 2.4245754245754245
# Network: 350
# Clustering Coefficient: 0.08382590005373455
# Average Shortest Path Length: 2.4189144189144187
# Network: 351
# Clustering Coefficient: 0.09796573875802998
# Average Shortest Path Length: 2.4142524142524144
# Network: 352
# Clustering Coefficient: 0.10638297872340426
# Average Shortest Path Length: 2.4355644355644355
# Network: 353
# Clustering Coefficient: 0.08466453674121406
# Average Shortest Path Length: 2.41025641025641
# Network: 354
# Clustering Coefficient: 0.08530805687203792
# Average Shortest Path Length: 2.4252414252414254
# Network: 355
# Clustering Coefficient: 0.09717868338557993
# Average Shortest Path Length: 2.4368964368964368
# Network: 356
# Clustering Coefficient: 0.08125677139761647
# Average Shortest Path Length: 2.405261405261405
# Network: 357
# Clustering Coefficient: 0.07425742574257425
# Average Shortest Path Length: 2.415917415917416
# Network: 358
# Clustering Coefficient: 0.0913312693498452
# Average Shortest Path Length: 2.404262404262404
# Network: 359
# Clustering Coefficient: 0.09448818897637795
# Average Shortest Path Length: 2.4325674325674327
# Network: 360
# Clustering Coefficient: 0.1015625
# Average Shortest Path Length: 2.42990342990343
# Network: 361
# Clustering Coefficient: 0.096051227321238
# Average Shortest Path Length: 2.434232434232434
# Network: 362
# Clustering Coefficient: 0.09319764327798608
# Average Shortest Path Length: 2.422244422244422
# Network: 363
# Clustering Coefficient: 0.11425630468347915
# Average Shortest Path Length: 2.4425574425574426
# Network: 364
# Clustering Coefficient: 0.07362924281984334
# Average Shortest Path Length: 2.411255411255411
# Network: 365
# Clustering Coefficient: 0.09153077327722252
# Average Shortest Path Length: 2.4189144189144187
# Network: 366
# Clustering Coefficient: 0.09135399673735727
# Average Shortest Path Length: 2.4235764235764234
# Network: 367
# Clustering Coefficient: 0.08177445216461784
# Average Shortest Path Length: 2.4022644022644024
# Network: 368
# Clustering Coefficient: 0.08945686900958466
# Average Shortest Path Length: 2.4235764235764234
# Network: 369
# Clustering Coefficient: 0.08154730789336122
# Average Shortest Path Length: 2.406926406926407
# Network: 370
# Clustering Coefficient: 0.09030612244897959
# Average Shortest Path Length: 2.416250416250416
# Network: 371
# Clustering Coefficient: 0.08589276418532014
# Average Shortest Path Length: 2.4195804195804196
# Network: 372
# Clustering Coefficient: 0.07577319587628865
# Average Shortest Path Length: 2.416583416583417
# Network: 373
# Clustering Coefficient: 0.10531594784353059
# Average Shortest Path Length: 2.450882450882451
# Network: 374
# Clustering Coefficient: 0.08665966386554622
# Average Shortest Path Length: 2.4202464202464204
# Network: 375
# Clustering Coefficient: 0.08655416439847577
# Average Shortest Path Length: 2.4235764235764234
# Network: 376
# Clustering Coefficient: 0.08171817705605029
# Average Shortest Path Length: 2.421245421245421
# Network: 377
# Clustering Coefficient: 0.07547169811320754
# Average Shortest Path Length: 2.417915417915418
# Network: 378
# Clustering Coefficient: 0.0973404255319149
# Average Shortest Path Length: 2.4072594072594073
# Network: 379
# Clustering Coefficient: 0.08272632674297607
# Average Shortest Path Length: 2.4132534132534134
# Network: 380
# Clustering Coefficient: 0.08539205155746508
# Average Shortest Path Length: 2.4305694305694305
# Network: 381
# Clustering Coefficient: 0.0861244019138756
# Average Shortest Path Length: 2.416583416583417
# Network: 382
# Clustering Coefficient: 0.1012987012987013
# Average Shortest Path Length: 2.433233433233433
# Network: 383
# Clustering Coefficient: 0.0705697856769472
# Average Shortest Path Length: 2.4082584082584084
# Network: 384
# Clustering Coefficient: 0.0720384204909285
# Average Shortest Path Length: 2.417915417915418
# Network: 385
# Clustering Coefficient: 0.08168713294180459
# Average Shortest Path Length: 2.4195804195804196
# Network: 386
# Clustering Coefficient: 0.07972902553413236
# Average Shortest Path Length: 2.415917415917416
# Network: 387
# Clustering Coefficient: 0.09820485744456177
# Average Shortest Path Length: 2.414918414918415
# Network: 388
# Clustering Coefficient: 0.10284810126582279
# Average Shortest Path Length: 2.4312354312354314
# Network: 389
# Clustering Coefficient: 0.08499475341028331
# Average Shortest Path Length: 2.4495504495504496
# Network: 390
# Clustering Coefficient: 0.09104938271604938
# Average Shortest Path Length: 2.4302364302364303
# Network: 391
# Clustering Coefficient: 0.10413476263399694
# Average Shortest Path Length: 2.4315684315684316
# Network: 392
# Clustering Coefficient: 0.11023622047244094
# Average Shortest Path Length: 2.4465534465534464
# Network: 393
# Clustering Coefficient: 0.07865168539325842
# Average Shortest Path Length: 2.42990342990343
# Network: 394
# Clustering Coefficient: 0.09309791332263243
# Average Shortest Path Length: 2.444888444888445
# Network: 395
# Clustering Coefficient: 0.0843558282208589
# Average Shortest Path Length: 2.4182484182484183
# Network: 396
# Clustering Coefficient: 0.09345794392523364
# Average Shortest Path Length: 2.4245754245754245
# Network: 397
# Clustering Coefficient: 0.0944386149003148
# Average Shortest Path Length: 2.4252414252414254
# Network: 398
# Clustering Coefficient: 0.09129738387613455
# Average Shortest Path Length: 2.4232434232434232
# Network: 399
# Clustering Coefficient: 0.07366771159874608
# Average Shortest Path Length: 2.4242424242424243
# Network: 400
# Clustering Coefficient: 0.09478935698447893
# Average Shortest Path Length: 2.4155844155844157
# Network: 401
# Clustering Coefficient: 0.08478931140801645
# Average Shortest Path Length: 2.4075924075924076
# Network: 402
# Clustering Coefficient: 0.08974358974358974
# Average Shortest Path Length: 2.4005994005994005
# Network: 403
# Clustering Coefficient: 0.09109947643979058
# Average Shortest Path Length: 2.421911421911422
# Network: 404
# Clustering Coefficient: 0.11273792093704246
# Average Shortest Path Length: 2.468198468198468
# Network: 405
# Clustering Coefficient: 0.09028511087645195
# Average Shortest Path Length: 2.4325674325674327
# Network: 406
# Clustering Coefficient: 0.09018987341772151
# Average Shortest Path Length: 2.427905427905428
# Network: 407
# Clustering Coefficient: 0.0873015873015873
# Average Shortest Path Length: 2.4265734265734267
# Network: 408
# Clustering Coefficient: 0.08487486398258977
# Average Shortest Path Length: 2.4412254412254413
# Network: 409
# Clustering Coefficient: 0.08441896821261073
# Average Shortest Path Length: 2.4079254079254078
# Network: 410
# Clustering Coefficient: 0.0690015682174595
# Average Shortest Path Length: 2.378673957621326
# Network: 411
# Clustering Coefficient: 0.09380053908355795
# Average Shortest Path Length: 2.423909423909424
# Network: 412
# Clustering Coefficient: 0.0995405819295559
# Average Shortest Path Length: 2.4335664335664338
# Network: 413
# Clustering Coefficient: 0.09617373319544985
# Average Shortest Path Length: 2.417915417915418
# Network: 414
# Clustering Coefficient: 0.096051227321238
# Average Shortest Path Length: 2.4252414252414254
# Network: 415
# Clustering Coefficient: 0.09712793733681462
# Average Shortest Path Length: 2.421911421911422
# Network: 416
# Clustering Coefficient: 0.10586403736377789
# Average Shortest Path Length: 2.4465534465534464
# Network: 417
# Clustering Coefficient: 0.08864696734059098
# Average Shortest Path Length: 2.4358974358974357
# Network: 418
# Clustering Coefficient: 0.08132992327365729
# Average Shortest Path Length: 2.41025641025641
# Network: 419
# Clustering Coefficient: 0.09712793733681462
# Average Shortest Path Length: 2.45021645021645
# Network: 420
# Clustering Coefficient: 0.09767441860465116
# Average Shortest Path Length: 2.4262404262404265
# Network: 421
# Clustering Coefficient: 0.11752249867654843
# Average Shortest Path Length: 2.4425574425574426
# Network: 422
# Clustering Coefficient: 0.07814992025518341
# Average Shortest Path Length: 2.394938394938395
# Network: 423
# Clustering Coefficient: 0.08256880733944955
# Average Shortest Path Length: 2.4368964368964368
# Network: 424
# Clustering Coefficient: 0.11430062630480167
# Average Shortest Path Length: 2.4129204129204127
# Network: 425
# Clustering Coefficient: 0.09165302782324058
# Average Shortest Path Length: 2.4132534132534134
# Network: 426
# Clustering Coefficient: 0.09872611464968153
# Average Shortest Path Length: 2.4195804195804196
# Network: 427
# Clustering Coefficient: 0.10259067357512953
# Average Shortest Path Length: 2.422244422244422
# Network: 428
# Clustering Coefficient: 0.0752
# Average Shortest Path Length: 2.425907425907426
# Network: 429
# Clustering Coefficient: 0.10020554984583761
# Average Shortest Path Length: 2.4309024309024307
# Network: 430
# Clustering Coefficient: 0.08450704225352113
# Average Shortest Path Length: 2.4129204129204127
# Network: 431
# Clustering Coefficient: 0.10138248847926268
# Average Shortest Path Length: 2.403263403263403
# Network: 432
# Clustering Coefficient: 0.09249743062692703
# Average Shortest Path Length: 2.4242424242424243
# Network: 433
# Clustering Coefficient: 0.10868407032498668
# Average Shortest Path Length: 2.4215784215784217
# Network: 434
# Clustering Coefficient: 0.09370119729307652
# Average Shortest Path Length: 2.4658674658674657
# Network: 435
# Clustering Coefficient: 0.10574018126888217
# Average Shortest Path Length: 2.397812713602187
# Network: 436
# Clustering Coefficient: 0.08201892744479496
# Average Shortest Path Length: 2.42990342990343
# Network: 437
# Clustering Coefficient: 0.08108108108108109
# Average Shortest Path Length: 2.4242424242424243
# Network: 438
# Clustering Coefficient: 0.098256735340729
# Average Shortest Path Length: 2.4292374292374292
# Network: 439
# Clustering Coefficient: 0.09071949947862357
# Average Shortest Path Length: 2.423909423909424
# Network: 440
# Clustering Coefficient: 0.08244274809160305
# Average Shortest Path Length: 2.428238428238428
# Network: 441
# Clustering Coefficient: 0.08722741433021806
# Average Shortest Path Length: 2.4312354312354314
# Network: 442
# Clustering Coefficient: 0.10824742268041238
# Average Shortest Path Length: 2.4309024309024307
# Network: 443
# Clustering Coefficient: 0.08328796951551443
# Average Shortest Path Length: 2.4255744255744256
# Network: 444
# Clustering Coefficient: 0.09559214020180563
# Average Shortest Path Length: 2.4265734265734267
# Network: 445
# Clustering Coefficient: 0.09506493506493506
# Average Shortest Path Length: 2.389952153110048
# Network: 446
# Clustering Coefficient: 0.11514841351074719
# Average Shortest Path Length: 2.4302364302364303
# Network: 447
# Clustering Coefficient: 0.10268562401263823
# Average Shortest Path Length: 2.4225774225774224
# Network: 448
# Clustering Coefficient: 0.08874801901743265
# Average Shortest Path Length: 2.411255411255411
# Network: 449
# Clustering Coefficient: 0.08441896821261073
# Average Shortest Path Length: 2.3972693972693975
# Network: 450
# Clustering Coefficient: 0.1
# Average Shortest Path Length: 2.4395604395604398
# Network: 451
# Clustering Coefficient: 0.07961783439490445
# Average Shortest Path Length: 2.4082584082584084
# Network: 452
# Clustering Coefficient: 0.08170606372045221
# Average Shortest Path Length: 2.4142524142524144
# Network: 453
# Clustering Coefficient: 0.08950452850293021
# Average Shortest Path Length: 2.4065934065934065
# Network: 454
# Clustering Coefficient: 0.08387096774193549
# Average Shortest Path Length: 2.405261405261405
# Network: 455
# Clustering Coefficient: 0.08716323296354993
# Average Shortest Path Length: 2.438228438228438
# Network: 456
# Clustering Coefficient: 0.08006279434850863
# Average Shortest Path Length: 2.423909423909424
# Network: 457
# Clustering Coefficient: 0.11271230056613485
# Average Shortest Path Length: 2.410589410589411
# Network: 458
# Clustering Coefficient: 0.07700709994538503
# Average Shortest Path Length: 2.391941391941392
# ...
# Average Shortest Path Length: 2.421911421911422
# Network: 858
# Clustering Coefficient: 0.08307210031347963
# Average Shortest Path Length: 2.4002664002664003
# Network: 859
# Clustering Coefficient: 0.0875
# Average Shortest Path Length: 2.420912420912421
# Network: 860
# Clustering Coefficient: 0.09403905447070915
# Average Shortest Path Length: 2.415917415917416
# Network: 861
# Clustering Coefficient: 0.09244992295839753
# Average Shortest Path Length: 2.41991341991342
# Network: 862
# Clustering Coefficient: 0.08892355694227769
# Average Shortest Path Length: 2.408924408924409
# Network: 863
# Clustering Coefficient: 0.09636650868878358
# Average Shortest Path Length: 2.4125874125874125
# Network: 864
# Clustering Coefficient: 0.07332624867162593
# Average Shortest Path Length: 2.4012654012654013
# Network: 865
# Clustering Coefficient: 0.09039836567926456
# Average Shortest Path Length: 2.434232434232434
# Network: 866
# Clustering Coefficient: 0.09365244536940687
# Average Shortest Path Length: 2.422244422244422
# Network: 867
# Clustering Coefficient: 0.10042507970244421
# Average Shortest Path Length: 2.4185814185814185
# Network: 868
# Clustering Coefficient: 0.0794912559618442
# Average Shortest Path Length: 2.422910422910423
# Network: 869
# Clustering Coefficient: 0.10164107993647432
# Average Shortest Path Length: 2.416583416583417
# Network: 870
# Clustering Coefficient: 0.0707774798927614
# Average Shortest Path Length: 2.404262404262404
# Network: 871
# Clustering Coefficient: 0.08955223880597014
# Average Shortest Path Length: 2.439227439227439
# Network: 872
# Clustering Coefficient: 0.08691153647180548
# Average Shortest Path Length: 2.408924408924409
# Network: 873
# Clustering Coefficient: 0.09086161879895562
# Average Shortest Path Length: 2.402939166097061
# Network: 874
# Clustering Coefficient: 0.07389937106918239
# Average Shortest Path Length: 2.417249417249417
# Network: 875
# Clustering Coefficient: 0.10164107993647432
# Average Shortest Path Length: 2.4358974358974357
# Network: 876
# Clustering Coefficient: 0.0824524312896406
# Average Shortest Path Length: 2.434898434898435
# Network: 877
# Clustering Coefficient: 0.10386965376782077
# Average Shortest Path Length: 2.4122544122544123
# Network: 878
# Clustering Coefficient: 0.112
# Average Shortest Path Length: 2.4405594405594404
# Network: 879
# Clustering Coefficient: 0.09105180533751962
# Average Shortest Path Length: 2.409257409257409
# Network: 880
# Clustering Coefficient: 0.08428720083246619
# Average Shortest Path Length: 2.4352314352314353
# Network: 881
# Clustering Coefficient: 0.07735946364105209
# Average Shortest Path Length: 2.415917415917416
# Network: 882
# Clustering Coefficient: 0.08492022645393721
# Average Shortest Path Length: 2.431901431901432
# Network: 883
# Clustering Coefficient: 0.07407407407407407
# Average Shortest Path Length: 2.41991341991342
# Network: 884
# Clustering Coefficient: 0.08179012345679013
# Average Shortest Path Length: 2.4295704295704295
# Network: 885
# Clustering Coefficient: 0.09262166405023547
# Average Shortest Path Length: 2.4202464202464204
# Network: 886
# Clustering Coefficient: 0.09779338014042126
# Average Shortest Path Length: 2.419002050580998
# Network: 887
# Clustering Coefficient: 0.0968766543144521
# Average Shortest Path Length: 2.456876456876457
# Network: 888
# Clustering Coefficient: 0.10328638497652583
# Average Shortest Path Length: 2.4295704295704295
# Network: 889
# Clustering Coefficient: 0.11717576364546821
# Average Shortest Path Length: 2.4358974358974357
# Network: 890
# Clustering Coefficient: 0.09473684210526316
# Average Shortest Path Length: 2.413919413919414
# Network: 891
# Clustering Coefficient: 0.09682457053617907
# Average Shortest Path Length: 2.4415584415584415
# Network: 892
# Clustering Coefficient: 0.08481675392670157
# Average Shortest Path Length: 2.4235764235764234
# Network: 893
# Clustering Coefficient: 0.10166756320602474
# Average Shortest Path Length: 2.426906426906427
# Network: 894
# Clustering Coefficient: 0.08525469168900804
# Average Shortest Path Length: 2.44022644022644
# Network: 895
# Clustering Coefficient: 0.09278350515463918
# Average Shortest Path Length: 2.4242424242424243
# Network: 896
# Clustering Coefficient: 0.11060606060606061
# Average Shortest Path Length: 2.4355644355644355
# Network: 897
# Clustering Coefficient: 0.09249743062692703
# Average Shortest Path Length: 2.445887445887446
# Network: 898
# Clustering Coefficient: 0.07428872497365648
# Average Shortest Path Length: 2.4232434232434232
# Network: 899
# Clustering Coefficient: 0.0865533230293663
# Average Shortest Path Length: 2.4055944055944054
# Network: 900
# Clustering Coefficient: 0.1043872919818457
# Average Shortest Path Length: 2.4428904428904428
# Network: 901
# Clustering Coefficient: 0.07819148936170213
# Average Shortest Path Length: 2.416583416583417
# Network: 902
# Clustering Coefficient: 0.09204368174726989
# Average Shortest Path Length: 2.4368964368964368
# Network: 903
# Clustering Coefficient: 0.0843501326259947
# Average Shortest Path Length: 2.4249084249084247
# Network: 904
# Clustering Coefficient: 0.093603744149766
# Average Shortest Path Length: 2.4155844155844157
# Network: 905
# Clustering Coefficient: 0.0895748987854251
# Average Shortest Path Length: 2.387279387279387
# Network: 906
# Clustering Coefficient: 0.09267015706806282
# Average Shortest Path Length: 2.4155844155844157
# Network: 907
# Clustering Coefficient: 0.08855515277058519
# Average Shortest Path Length: 2.4132534132534134
# Network: 908
# Clustering Coefficient: 0.09302325581395349
# Average Shortest Path Length: 2.4299384825700616
# Network: 909
# Clustering Coefficient: 0.08320251177394035
# Average Shortest Path Length: 2.4135864135864136
# Network: 910
# Clustering Coefficient: 0.08472803347280335
# Average Shortest Path Length: 2.4302364302364303
# Network: 911
# Clustering Coefficient: 0.07940709370037057
# Average Shortest Path Length: 2.411255411255411
# Network: 912
# Clustering Coefficient: 0.07515657620041753
# Average Shortest Path Length: 2.382284382284382
# Network: 913
# Clustering Coefficient: 0.07058823529411765
# Average Shortest Path Length: 2.4005994005994005
# Network: 914
# Clustering Coefficient: 0.1004119464469619
# Average Shortest Path Length: 2.432234432234432
# Network: 915
# Clustering Coefficient: 0.09830866807610994
# Average Shortest Path Length: 2.4358974358974357
# Network: 916
# Clustering Coefficient: 0.08695652173913043
# Average Shortest Path Length: 2.426906426906427
# Network: 917
# Clustering Coefficient: 0.08284652150823155
# Average Shortest Path Length: 2.439227439227439
# Network: 918
# Clustering Coefficient: 0.0984375
# Average Shortest Path Length: 2.4415584415584415
# Network: 919
# Clustering Coefficient: 0.0981012658227848
# Average Shortest Path Length: 2.4265734265734267
# Network: 920
# Clustering Coefficient: 0.10410094637223975
# Average Shortest Path Length: 2.4275724275724277
# Network: 921
# Clustering Coefficient: 0.08125331917153479
# Average Shortest Path Length: 2.4085914085914086
# Network: 922
# Clustering Coefficient: 0.08643268727082241
# Average Shortest Path Length: 2.40992340992341
# Network: 923
# Clustering Coefficient: 0.07776049766718507
# Average Shortest Path Length: 2.3991797676008204
# Network: 924
# Clustering Coefficient: 0.10396785534907081
# Average Shortest Path Length: 2.3947368421052633
# Network: 925
# Clustering Coefficient: 0.1195097037793667
# Average Shortest Path Length: 2.432900432900433
# Network: 926
# Clustering Coefficient: 0.09846153846153846
# Average Shortest Path Length: 2.4192474192474194
# Network: 927
# Clustering Coefficient: 0.09298780487804878
# Average Shortest Path Length: 2.41025641025641
# Network: 928
# Clustering Coefficient: 0.08121019108280254
# Average Shortest Path Length: 2.3996003996003994
# Network: 929
# Clustering Coefficient: 0.09273570324574962
# Average Shortest Path Length: 2.409257409257409
# Network: 930
# Clustering Coefficient: 0.09472049689440994
# Average Shortest Path Length: 2.4175824175824174
# Network: 931
# Clustering Coefficient: 0.09379968203497616
# Average Shortest Path Length: 2.42990342990343
# Network: 932
# Clustering Coefficient: 0.08585055643879173
# Average Shortest Path Length: 2.43989343989344
# Network: 933
# Clustering Coefficient: 0.10074626865671642
# Average Shortest Path Length: 2.428904428904429
# Network: 934
# Clustering Coefficient: 0.10275038920601973
# Average Shortest Path Length: 2.4275724275724277
# Network: 935
# Clustering Coefficient: 0.10681114551083591
# Average Shortest Path Length: 2.423909423909424
# Network: 936
# Clustering Coefficient: 0.10051546391752578
# Average Shortest Path Length: 2.4312354312354314
# Network: 937
# Clustering Coefficient: 0.08763693270735524
# Average Shortest Path Length: 2.4352314352314353
# Network: 938
# Clustering Coefficient: 0.08704663212435233
# Average Shortest Path Length: 2.4035964035964037
# Network: 939
# Clustering Coefficient: 0.08064516129032258
# Average Shortest Path Length: 2.415917415917416
# Network: 940
# Clustering Coefficient: 0.0970724191063174
# Average Shortest Path Length: 2.4079254079254078
# Network: 941
# Clustering Coefficient: 0.09566126502875065
# Average Shortest Path Length: 2.4292374292374292
# Network: 942
# Clustering Coefficient: 0.11288659793814433
# Average Shortest Path Length: 2.4202464202464204
# Network: 943
# Clustering Coefficient: 0.09828141783029001
# Average Shortest Path Length: 2.4232434232434232
# Network: 944
# Clustering Coefficient: 0.08909287257019438
# Average Shortest Path Length: 2.4315684315684316
# Network: 945
# Clustering Coefficient: 0.08711721224920803
# Average Shortest Path Length: 2.4472194472194473
# Network: 946
# Clustering Coefficient: 0.0995850622406639
# Average Shortest Path Length: 2.4262404262404265
# Network: 947
# Clustering Coefficient: 0.08158995815899582
# Average Shortest Path Length: 2.404928404928405
# Network: 948
# Clustering Coefficient: 0.0962566844919786
# Average Shortest Path Length: 2.4315684315684316
# Network: 949
# Clustering Coefficient: 0.09302325581395349
# Average Shortest Path Length: 2.4122544122544123
# Network: 950
# Clustering Coefficient: 0.1127348643006263
# Average Shortest Path Length: 2.4309024309024307
# Network: 951
# Clustering Coefficient: 0.11392405063291139
# Average Shortest Path Length: 2.4189144189144187
# Network: 952
# Clustering Coefficient: 0.09429941395844432
# Average Shortest Path Length: 2.415917415917416
# Network: 953
# Clustering Coefficient: 0.08992248062015504
# Average Shortest Path Length: 2.4285714285714284
# Network: 954
# Clustering Coefficient: 0.09076682316118936
# Average Shortest Path Length: 2.406926406926407
# Network: 955
# Clustering Coefficient: 0.0898109243697479
# Average Shortest Path Length: 2.4082584082584084
# Network: 956
# Clustering Coefficient: 0.10164107993647432
# Average Shortest Path Length: 2.4375624375624376
# Network: 957
# Clustering Coefficient: 0.10091743119266056
# Average Shortest Path Length: 2.4418914418914417
# Network: 958
# Clustering Coefficient: 0.08431272355646398
# Average Shortest Path Length: 2.416583416583417
# Network: 959
# Clustering Coefficient: 0.1
# Average Shortest Path Length: 2.4145854145854146
# Network: 960
# Clustering Coefficient: 0.08535300316122234
# Average Shortest Path Length: 2.4285714285714284
# Network: 961
# Clustering Coefficient: 0.0999487442337263
# Average Shortest Path Length: 2.422244422244422
# Network: 962
# Clustering Coefficient: 0.09467149508535955
# Average Shortest Path Length: 2.4205794205794207
# Network: 963
# Clustering Coefficient: 0.08804347826086957
# Average Shortest Path Length: 2.4285714285714284
# Network: 964
# Clustering Coefficient: 0.08531540847983454
# Average Shortest Path Length: 2.4065934065934065
# Network: 965
# Clustering Coefficient: 0.0791974656810982
# Average Shortest Path Length: 2.3972693972693975
# Network: 966
# Clustering Coefficient: 0.08762612851832183
# Average Shortest Path Length: 2.4129204129204127
# Network: 967
# Clustering Coefficient: 0.08236536430834214
# Average Shortest Path Length: 2.3926073926073927
# Network: 968
# Clustering Coefficient: 0.09023746701846966
# Average Shortest Path Length: 2.416916416916417
# Network: 969
# Clustering Coefficient: 0.08700322234156821
# Average Shortest Path Length: 2.4405594405594404
# Network: 970
# Clustering Coefficient: 0.09831029185867896
# Average Shortest Path Length: 2.4345654345654344
# Network: 971
# Clustering Coefficient: 0.08500772797527048
# Average Shortest Path Length: 2.415251415251415
# Network: 972
# Clustering Coefficient: 0.08249603384452671
# Average Shortest Path Length: 2.3972693972693975
# Network: 973
# Clustering Coefficient: 0.10010427528675704
# Average Shortest Path Length: 2.4085914085914086
# Network: 974
# Clustering Coefficient: 0.09284951974386339
# Average Shortest Path Length: 2.4405594405594404
# Network: 975
# Clustering Coefficient: 0.07820646506777894
# Average Shortest Path Length: 2.415251415251415
# Network: 976
# Clustering Coefficient: 0.06732776617954071
# Average Shortest Path Length: 2.415917415917416
# Network: 977
# Clustering Coefficient: 0.09916054564533054
# Average Shortest Path Length: 2.415917415917416
# Network: 978
# Clustering Coefficient: 0.10697179350718468
# Average Shortest Path Length: 2.421911421911422
# Network: 979
# Clustering Coefficient: 0.09886714727085479
# Average Shortest Path Length: 2.432900432900433
# Network: 980
# Clustering Coefficient: 0.09860557768924302
# Average Shortest Path Length: 2.396103896103896
# Network: 981
# Clustering Coefficient: 0.08589607635206786
# Average Shortest Path Length: 2.4055944055944054
# Network: 982
# Clustering Coefficient: 0.0707395498392283
# Average Shortest Path Length: 2.3792873792873794
# Network: 983
# Clustering Coefficient: 0.08133971291866028
# Average Shortest Path Length: 2.4155844155844157
# Network: 984
# Clustering Coefficient: 0.08171817705605029
# Average Shortest Path Length: 2.4132534132534134
# Network: 985
# Clustering Coefficient: 0.09480122324159021
# Average Shortest Path Length: 2.417249417249417
# Network: 986
# Clustering Coefficient: 0.10172228202368137
# Average Shortest Path Length: 2.4255744255744256
# Network: 987
# Clustering Coefficient: 0.11216429699842022
# Average Shortest Path Length: 2.421245421245421
# Network: 988
# Clustering Coefficient: 0.08638743455497382
# Average Shortest Path Length: 2.4292374292374292
# Network: 989
# Clustering Coefficient: 0.07786016949152542
# Average Shortest Path Length: 2.4035964035964037
# Network: 990
# Clustering Coefficient: 0.08870967741935484
# Average Shortest Path Length: 2.4365634365634365
# Network: 991
# Clustering Coefficient: 0.11462047885888946
# Average Shortest Path Length: 2.4205794205794207
# Network: 992
# Clustering Coefficient: 0.10454545454545454
# Average Shortest Path Length: 2.434232434232434
# Network: 993
# Clustering Coefficient: 0.08781266631186802
# Average Shortest Path Length: 2.420912420912421
# Network: 994
# Clustering Coefficient: 0.09628886659979939
# Average Shortest Path Length: 2.4358974358974357
# Network: 995
# Clustering Coefficient: 0.09128416709644147
# Average Shortest Path Length: 2.4142524142524144
# Network: 996
# Clustering Coefficient: 0.0735140771637122
# Average Shortest Path Length: 2.4082584082584084
# Network: 997
# Clustering Coefficient: 0.0845953002610966
# Average Shortest Path Length: 2.434898434898435
# Network: 998
# Clustering Coefficient: 0.09717868338557993
# Average Shortest Path Length: 2.426906426906427
# Network: 999
# Clustering Coefficient: 0.09799789251844046
# Average Shortest Path Length: 2.403929403929404
# Network: 1000
# Clustering Coefficient: 0.08566978193146417
# Average Shortest Path Length: 2.4252414252414254
# Mean Clustering Coefficient: 0.09076588775222286
# Mean Average Shortest Path Length: 2.4200804458699197
#      Network  Clustering Coefficient  Average Shortest Path Length
# 0          1                0.087144                      2.425907
# 1          2                0.083376                      2.401931
# 2          3                0.100661                      2.409923
# 3          4                0.098972                      2.415917
# 4          5                0.102761                      2.405332
# ..       ...                     ...                           ...
# 995      996                0.073514                      2.408258
# 996      997                0.084595                      2.434898
# 997      998                0.097179                      2.426906
# 998      999                0.097998                      2.403929
# 999     1000                0.085670                      2.425241
#
# [1000 rows x 3 columns]

# %%
df
# Out:
#      Network  Clustering Coefficient  Average Shortest Path Length
# 0          1                0.087144                      2.425907
# 1          2                0.083376                      2.401931
# 2          3                0.100661                      2.409923
# 3          4                0.098972                      2.415917
# 4          5                0.102761                      2.405332
# ..       ...                     ...                           ...
# 995      996                0.073514                      2.408258
# 996      997                0.084595                      2.434898
# 997      998                0.097179                      2.426906
# 998      999                0.097998                      2.403929
# 999     1000                0.085670                      2.425241
#
# [1000 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot histogram using Seaborn
sns.axes_style("ticks")
plt.figure(figsize=(10, 6))
sns.histplot(df["Clustering Coefficient"], bins=20)
plt.axvline(x=0.610, color='r', linestyle='--', label='Clustering Coefficient for our Network: 0.610')
plt.title("Histogram of Clustering Coefficient")
plt.xlabel("Clustering Coefficient", weight='bold', fontsize=16)
plt.ylabel("Frequency", weight='bold', fontsize=16)

# Add text annotation
plt.text(0.58, 25, 'Clustering Coefficient of \nIFN-$\gamma$ Signalling Network: 0.610\n', color='red', fontsize=14, rotation=90, horizontalalignment='center')


# Set tick parameters
plt.tick_params(axis='both', labelsize=16, colors='black')

# Remove gridlines
# plt.grid(False)
plt.savefig("Clustering_Coefficient_histo.png", dpi=500)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot histogram using Seaborn
sns.axes_style("ticks")
plt.figure(figsize=(10, 6))
sns.histplot(df["Average Shortest Path Length"], bins=20)
# plt.axvline(x=0.610, color='r', linestyle='--', label='Clustering Coefficient for our Network: 0.610')
plt.title("Histogram of Average Shortest Path Length")
plt.xlabel("Average Shortest Path Length", weight='bold', fontsize=16)
plt.ylabel("Frequency", weight='bold', fontsize=16)
plt.axvline(x=2.553, color='r', linestyle='--', label='Average Shortest Path Length of WT Network: 2.553')
plt.text(2.54, 20, 'Average Shortest Path Length of \nIFN-$\gamma$ Signalling Network: 2.553', color='red', fontsize=14, rotation=90,horizontalalignment='center')
# Add text annotation
# plt.text(0.58, 25, 'Clustering Coefficient of \nIFN-$\gamma$ Signalling Network: 0.610\n', color='red', fontsize=14, rotation=90, horizontalalignment='center')


# Set tick parameters
plt.tick_params(axis='both', labelsize=16, colors='black')

# Remove gridlines
# plt.grid(False)
plt.savefig("Average_Shortest_histo.png", dpi=500)
plt.show()

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt

# # Plot histogram using Seaborn
# plt.figure(figsize=(10, 6))
# sns.histplot(df["Average Shortest Path Length"], bins=20)
# plt.axvline(x=2.553, color='r', linestyle='--', label='Average Shortest Path Length: 2.553')
# plt.title("Histogram of Average Shortest Path Length")
# plt.xlabel("Average Shortest Path Length")
# plt.ylabel("Frequency")
# plt.legend()
# plt.show()
